# %%
import glob
import pandas as pd
import re
import os
import sqlite3
import numpy as np

daumNews_dir = glob.glob('./glob_test2/*.csv')


def preprocessing_articles(data):
    contents_new = []
    for content in data['content']:
        # content = content.fillna("")
        content = str(content).split('\n')
        content = list(filter(lambda s: len(s) > 3, content))

        # 글 마지막에 항상 기자의 메일 주소가 추가되어 있다. 그 이후로 나오는 글은 불필요하므로 삭제함
        for i in range(1, len(content)):
            if '@' in content[-i]:
                break
        if i == len(content) - 1:
            i = 1
        content_prep = content[:-i]

            # 너무 짧거나, 광고, copyright, 사진설명, 메일 등 불필요한 단어가 포함되어 있을 경우 불필요한 문장으로 판단하고 삭제 처리
        content_prep = list(filter(lambda s: len(s) > 30 and \
                                             '▶' not in s and \
                                             '©' not in s and \
                                             '▲' not in s and \
                                             '사진=' not in s and \
                                             '사진제공=' not in s and \
                                             '@' not in s and \
                                             not re.findall("기자 *$", s) and \
                                             not re.findall("제공 *$", s) and \
                                             not re.findall("이하", s) and \
                                             not re.findall("무단전재", s) and \
                                             not re.findall("기자 *= *", s), content_prep))

        # 언론사명이 들어간 prefix 삭제
        content_prep = list(map(lambda s: re.sub("\[.*\]", "", s), content_prep))  # [스포츠서울]
        content_prep = list(map(lambda s: re.sub("\(.*\=.*\)", "", s), content_prep))  # (서울=뉴시스)
        content_prep = list(map(lambda s: re.sub("\【.*\=.*\】", "", s), content_prep))  # 【파이낸셜뉴스 포천=강근주 기자】
        # content_prep = list(map(lambda s: re.sub('[^A-Za-z가-힣]',' ', s), content_prep)) # 한글 제외 영문, 한자, 숫자, 특수문자 모두 제거
        content_prep = list(map(lambda s: re.sub('[^가-힣]', ' ', s), content_prep))  # 한글 제외 영문, 한자, 숫자, 특수문자 모두 제거

        contents_new.append('\n'.join(content_prep))
        # print('for 안',len(contents_new))
    # cnt =+ 1
    # print(cnt, contents_new)
    # print('for 밖',len(contents_new))
    data['news_content'] = contents_new
    return data


if __name__ == "__main__":
    # con = sqlite3.connect("glob_test.db")   # 데이터베이스 이름
    # c = con.cursor()
    # c.execute('DROP TABLE IF EXISTS `news_dummy`;')
    # c.execute('''
    #         CREATE TABLE `news_dummy` (
    #             `news_id` INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT,
    #             `news_name` TEXT NOT NULL,
    #             `pubdate` TEXT NOT NULL,
    #             `url` TEXT NOT NULL,
    #             `news_content` TEXT NOT NULL
    #         );

    # ''')
    full_dataset = pd.DataFrame()
    for daumNews in daumNews_dir:
        df = pd.read_csv(daumNews, names=['order', 'news_name', 'pubdate', 'url', 'content'])  # 컬럼이름 지정
        df = df.drop(['order'], axis=1)
        # print(df)
        data_prep = preprocessing_articles(df)
        full_dataset = pd.concat([full_dataset, data_prep], axis=0)
        print(full_dataset)
        # print(data_prep)
        # data_prep['news_content'] = data_prep['news_content'].str.replace(' ', '')
        # data_prep['news_content'] = data_prep['news_content'].str.replace('\n',' ')
        # data_prep['news_content'] = data_prep['news_content'].str.strip()
        # data_prep['news_content'] = data_prep['news_content'].replace('', np.nan)    # 빈셀이 있는 행을 삭제하기 위해 NaN으로 변경
        # data_prep_drop = data_prep.dropna(axis=0)
        # data_prep_drop_dup = data_prep_drop.drop_duplicates(['news_content'], keep='first', inplace=False, ignore_index=True)   # 중복값 제거
        # result = data_prep_drop_dup[['news_name', 'pubdate', 'url', 'news_content']]  # 비교를 위해 content(원본데이터) 추가, news_content가 전처리된 데이터
        # print(result)
        # c = con.cursor()
        # result.to_sql('news_dummy', con, if_exists='append', index=False)         # DB에 news_dummy 라는 테이블 이름으로 저장

    # con.commit()
    # con.close()
# Out:
#                                             news_name              pubdate  \
# 0           수도권 등 '물폭탄'에 사망 1명·곳곳 침수..내일도 최대 80mm(종합)  2020. 08. 01. 23:59
# 1             '트레인' 윤시윤, 평행세계 자신 전화에 패닉 "차엽은 공범" (종합)  2020. 08. 01. 23:55
# 2                              하남 미사2동 취약계층 선풍기 55대전달  2020. 08. 01. 23:55
# 3        '온앤오프' 소유 "다이어트 중, 달걀+치즈 라면+소맥 먹고 싶어" [TV캡처]  2020. 08. 01. 23:55
# 4                    더불어민주당 홍성국 의원, 가상화폐 돈세탁 감독법 대표발의  2020. 08. 01. 23:55
# 5   '최애 엔터테인먼트' 계약서 도장 찍자마자 연습! 미션곡 '주라주라', '로꾸거!!...  2020. 08. 01. 23:54
# 6                  '계약갱신청구권' 위헌 여부 가리나..헌재에 헌법소원심판 청구  2020. 08. 01. 23:54
# 7                일본 신규 확진 또 1천500명대..지자체, 일부 상점 휴업 요청  2020. 08. 01. 23:54
# 8                    '한다다' 기도훈, 연상 오윤아에게 "좋아해도 되냐" 고백  2020. 08. 01. 23:53
# 9                 '전참시' 유이, 매니저 영도씨의 잦은 장트러블에 결국 '오열'  2020. 08. 01. 23:51
# 10   [스브스夜] '편의점 샛별이' 한선화, 지창욱 되찾기 위한 중상모략.."김유정 쫓아내"  2020. 08. 01. 23:51
# 11                    '전참시' 전현무, 녹화 중 급 화장실行 "너무 급해서"  2020. 08. 01. 23:51
# 12            '구해줘 홈즈' 강기영,일산·김포·파주 일대 2억 원대 전세 매물 찾기  2020. 08. 01. 23:50
# 13           첼시, 지난 1월 오바메양 영입 기회 있었다..'높은 연봉에 관심 철회'  2020. 08. 01. 23:50
# 14                        '사이코지만 괜찮아' 수간호사, 서예지 母로 반전  2020. 08. 01. 23:50
#
#                                        url  \
# 0   https://v.daum.net/v/20200801235926455
# 1   https://v.daum.net/v/20200801235556443
# 2   https://v.daum.net/v/20200801235522442
# 3   https://v.daum.net/v/20200801235511441
# 4   https://v.daum.net/v/20200801235505440
# 5   https://v.daum.net/v/20200801235428437
# 6   https://v.daum.net/v/20200801235408436
# 7   https://v.daum.net/v/20200801235401433
# 8   https://v.daum.net/v/20200801235311432
# 9   https://v.daum.net/v/20200801235102418
# 10  https://v.daum.net/v/20200801235101417
# 11  https://v.daum.net/v/20200801235100415
# 12  https://v.daum.net/v/20200801235022406
# 13  https://v.daum.net/v/20200801235005401
# 14  https://v.daum.net/v/20200801235003400
#
#                                               content  \
# 0   경기 파주시 이날 하루만 최대 124mm 폭우서울 도림천 80대 남성 구조..이송 ...
# 1   윤시윤이 평행세계 자신에게서 전화를 받았다. \n8월 1일 방송된 OCN 토일드라마...
# 2   하남 미사2동 취약계층 선풍기 55대 전달. 사진제공=하남시\n           ...
# 3   소유 / 사진=tvN 온앤오프\n           \n\n[스포츠투데이 김샛별 기...
# 4   빗썸 등 가상자산사업자도 금융당국에 자금세탁방지 업무 감독 받아야 \n\n\n\n ...
# 5   1일 방송된 '최애 엔터테인먼트'에서는 계약서에 도장 찍자마자 연습실로 향하는 최애...
# 6   사법시험준비생모임(사준모)은 계약갱신청구권제를 도입한 개정 주택임대차보호법이 임차인...
# 7   일본에서 오늘(1일) 1천536명의 코로나19 확진자가 추가됐습니다.\n이로써 NH...
# 8   한번 다녀왔습니다(사진=방송화면캡쳐)\n           \n\n\n'한 번 다녀...
# 9   [매일경제 스타투데이 손세현 객원기자]\n          \n배우 유이가 자신의 ...
# 10  [SBS funE | 김지수 에디터] 지창욱이 직영점 전환 제안을 받았다.\n1일 ...
# 11  MBC '전지적 참견 시점' 방송 화면 캡처 © 뉴스1\n           \n\...
# 12  '구해줘 홈즈' 강기영이 출연한다.MBC 제공\n           \n\n'구해줘...
# 13  [인터풋볼] 오종헌 기자= 첼시는 지난 1월 피에르 에메릭 오바메양(31, 아스널)...
# 14  사이코지만 괜찮아(사진=방송화면캡쳐)\n           \n\n\n수간호사 장영...
#
#                                          news_content
# 0   경기 파주시 이날 하루만 최대       폭우서울 도림천   대 남성 구조  이송 ...
# 1    월  일 방송된     토일드라마  트레인   회 극본 박가연 연출 류승진 이승훈...
# 2    하남시 미사 동행정복지센터는  월  일 미사 동 지역사회보장협의체와  하일위생환경...
# 3     온앤오프  소유가 뮤직비디오 촬영으로 인한 다이어트가 끝난 뒤 먹고 싶은 음식을...
# 4   빗썸 등 가상자산사업자도 금융당국에 자금세탁방지 업무 감독 받아야 \n       ...
# 5    일 방송된  최애 엔터테인먼트 에서는 계약서에 도장 찍자마자 연습실로 향하는 최애...
# 6   사법시험준비생모임 사준모 은 계약갱신청구권제를 도입한 개정 주택임대차보호법이 임차인...
# 7   일본에서 오늘  일   천   명의 코로나   확진자가 추가됐습니다 \n이로써   ...
# 8    한 번 다녀왔습니다 에서 기도훈이  살 연상 오윤아에 고백했다  \n 일 오후 방...
# 9   배우 유이가 자신의 매니저 영도씨가 잦은 장트러블로 휴게소를 찾자 결국 오열해 주변...
# 10   지창욱이 직영점 전환 제안을 받았다 \n 일 방송된     금토드라마  편의점 샛...
# 11   일 오후 방송된      전지적 참견 시점 에서는 유이와 매니저 영도씨의 일상이 ...
# 12  복팀의 코디로 출격한 배우 강기영은  홈즈 의 애청자로 밝히며  일요일은  신비한 ...
# 13  오바메양은     년  월 독일 도르트문트를 떠나 아스널 유니폼을 입었다  시즌 도...
# 14   월  일 방송된     토일드라마  사이코지만 괜찮아    회에서 고문영 서예지 ...
#                                             news_name              pubdate  \
# 0           수도권 등 '물폭탄'에 사망 1명·곳곳 침수..내일도 최대 80mm(종합)  2020. 08. 01. 23:59
# 1             '트레인' 윤시윤, 평행세계 자신 전화에 패닉 "차엽은 공범" (종합)  2020. 08. 01. 23:55
# 2                              하남 미사2동 취약계층 선풍기 55대전달  2020. 08. 01. 23:55
# 3        '온앤오프' 소유 "다이어트 중, 달걀+치즈 라면+소맥 먹고 싶어" [TV캡처]  2020. 08. 01. 23:55
# 4                    더불어민주당 홍성국 의원, 가상화폐 돈세탁 감독법 대표발의  2020. 08. 01. 23:55
# 5   '최애 엔터테인먼트' 계약서 도장 찍자마자 연습! 미션곡 '주라주라', '로꾸거!!...  2020. 08. 01. 23:54
# 6                  '계약갱신청구권' 위헌 여부 가리나..헌재에 헌법소원심판 청구  2020. 08. 01. 23:54
# 7                일본 신규 확진 또 1천500명대..지자체, 일부 상점 휴업 요청  2020. 08. 01. 23:54
# 8                    '한다다' 기도훈, 연상 오윤아에게 "좋아해도 되냐" 고백  2020. 08. 01. 23:53
# 9                 '전참시' 유이, 매니저 영도씨의 잦은 장트러블에 결국 '오열'  2020. 08. 01. 23:51
# 10   [스브스夜] '편의점 샛별이' 한선화, 지창욱 되찾기 위한 중상모략.."김유정 쫓아내"  2020. 08. 01. 23:51
# 11                    '전참시' 전현무, 녹화 중 급 화장실行 "너무 급해서"  2020. 08. 01. 23:51
# 12            '구해줘 홈즈' 강기영,일산·김포·파주 일대 2억 원대 전세 매물 찾기  2020. 08. 01. 23:50
# 13           첼시, 지난 1월 오바메양 영입 기회 있었다..'높은 연봉에 관심 철회'  2020. 08. 01. 23:50
# 14                        '사이코지만 괜찮아' 수간호사, 서예지 母로 반전  2020. 08. 01. 23:50
# 0    NC, 김해고 황금사자기 우승 축하 행사.."풀뿌리 야구 발전 돕는다" [엠스플 이슈]  2020. 08. 01. 23:50
# 1                '바둑 꿈나무 향연장' 조아바이톤 루키바둑리그, 본격 레이스 돌입  2020. 08. 01. 23:48
# 2                 '우아한 친구들' 유준상, 사강 만났다..김원해 비밀에 한 발짝  2020. 08. 01. 23:47
# 3                                조달청 우수조달물품 47개 제품 지정  2020. 08. 01. 23:46
# 4                 오늘도 버디만 7개..19세 유해란, '와이어 투 와이어' 예약  2020. 08. 01. 23:45
# 5                           '23안타' 키움, 삼성 대파하고 5연승 질주  2020. 08. 01. 23:45
# 6                                 강한 비에 2호선 강남역 부근 침수  2020. 08. 01. 23:44
# 7            아이즈원 채원, 생일 기념 어린 시절 사진 공개..아기삵의 더 아기 시절  2020. 08. 01. 23:43
# 8                           두산, 연장접전 끝 NC 꺾고 전날 패배 설욕  2020. 08. 01. 23:42
# 9         '전참시' 유이 "매니저, 속마음 다 이야기 하는 친구, 소개하고 싶어 출연"  2020. 08. 01. 23:42
# 10                           SUV가 경차·가로수 들이받아..운전자 도주  2020. 08. 01. 23:42
# 11                  '우아한 친구들' 김혜은, 남편 김성오 위해 김광규와 호텔행  2020. 08. 01. 23:41
# 12                        與 '부동산 입법' 속도..野 반발 속 대응 고심  2020. 08. 01. 23:40
# 13       '최민환♥︎' 율희, 삼남매 엄마의 일상 "이제는 다투기도 한다"[★SHOT!]  2020. 08. 01. 23:40
# 14           김빈우 "시모, 반려견 걱정에 손주 보러 안 와 조금 서운"[결정적장면]  2020. 08. 01. 23:39
#
#                                        url  \
# 0   https://v.daum.net/v/20200801235926455
# 1   https://v.daum.net/v/20200801235556443
# 2   https://v.daum.net/v/20200801235522442
# 3   https://v.daum.net/v/20200801235511441
# 4   https://v.daum.net/v/20200801235505440
# 5   https://v.daum.net/v/20200801235428437
# 6   https://v.daum.net/v/20200801235408436
# 7   https://v.daum.net/v/20200801235401433
# 8   https://v.daum.net/v/20200801235311432
# 9   https://v.daum.net/v/20200801235102418
# 10  https://v.daum.net/v/20200801235101417
# 11  https://v.daum.net/v/20200801235100415
# 12  https://v.daum.net/v/20200801235022406
# 13  https://v.daum.net/v/20200801235005401
# 14  https://v.daum.net/v/20200801235003400
# 0   https://v.daum.net/v/20200801235003399
# 1   https://v.daum.net/v/20200801234804392
# 2   https://v.daum.net/v/20200801234739388
# 3   https://v.daum.net/v/20200801234632378
# 4   https://v.daum.net/v/20200801234510367
# 5   https://v.daum.net/v/20200801234500363
# 6   https://v.daum.net/v/20200801234402356
# 7   https://v.daum.net/v/20200801234324355
# 8   https://v.daum.net/v/20200801234212354
# 9   https://v.daum.net/v/20200801234200353
# 10  https://v.daum.net/v/20200801234200352
# 11  https://v.daum.net/v/20200801234123351
# 12  https://v.daum.net/v/20200801234021348
# 13  https://v.daum.net/v/20200801234016347
# 14  https://v.daum.net/v/20200801233956345
#
#                                               content  \
# 0   경기 파주시 이날 하루만 최대 124mm 폭우서울 도림천 80대 남성 구조..이송 ...
# 1   윤시윤이 평행세계 자신에게서 전화를 받았다. \n8월 1일 방송된 OCN 토일드라마...
# 2   하남 미사2동 취약계층 선풍기 55대 전달. 사진제공=하남시\n           ...
# 3   소유 / 사진=tvN 온앤오프\n           \n\n[스포츠투데이 김샛별 기...
# 4   빗썸 등 가상자산사업자도 금융당국에 자금세탁방지 업무 감독 받아야 \n\n\n\n ...
# 5   1일 방송된 '최애 엔터테인먼트'에서는 계약서에 도장 찍자마자 연습실로 향하는 최애...
# 6   사법시험준비생모임(사준모)은 계약갱신청구권제를 도입한 개정 주택임대차보호법이 임차인...
# 7   일본에서 오늘(1일) 1천536명의 코로나19 확진자가 추가됐습니다.\n이로써 NH...
# 8   한번 다녀왔습니다(사진=방송화면캡쳐)\n           \n\n\n'한 번 다녀...
# 9   [매일경제 스타투데이 손세현 객원기자]\n          \n배우 유이가 자신의 ...
# 10  [SBS funE | 김지수 에디터] 지창욱이 직영점 전환 제안을 받았다.\n1일 ...
# 11  MBC '전지적 참견 시점' 방송 화면 캡처 © 뉴스1\n           \n\...
# 12  '구해줘 홈즈' 강기영이 출연한다.MBC 제공\n           \n\n'구해줘...
# 13  [인터풋볼] 오종헌 기자= 첼시는 지난 1월 피에르 에메릭 오바메양(31, 아스널)...
# 14  사이코지만 괜찮아(사진=방송화면캡쳐)\n           \n\n\n수간호사 장영...
# 0   시구자로 나선 김해고 김준수 투수와 시포자 박무승 감독(사진=NC)\n       ...
# 1   사진=한국기원 제공\n           \n\n[스포츠투데이 김호진 기자] 한국 ...
# 2   [엑스포츠뉴스 나금주 기자] '우아한 친구들' 유준상이 사강과 마주했다.\n1일 방...
# 3   올해 3번 째, 공공구매력을 활용한 혁신제품의 공공조달시장 진입 지원 \n\n\n[...
# 4   KLPGA 제주삼다수 마스터스 루키시즌 대회 2연패 눈앞이정은6 14언더파 2위.....
# 5   프로야구 키움 히어로즈가 23안타를 터뜨리며 삼성 라이온즈를 대파하고 5연승을 질주...
# 6   [ 김경림 기자 ]\n          \n\n\n\n\n\n\n지하철 2호선 강남...
# 7   8월 1일 아이즈원 SNS에는 “여러부우운 저는 여러분 덕분에 너무너무 행복한 21...
# 8   연장 10회말 1사 만루에서 유격수 김재호의 호수비로 승리를 지킨 두산 선수들이 그...
# 9   매경닷컴 MK스포츠 손진아 기자\n배우 유이가 ‘전지적 참견 시점’에 출연한 소감을...
# 10  오늘(1일) 저녁 7시 40분쯤 인천 만수동의 한 도로에서 SUV가 경차와 가로수를...
# 11  [뉴스엔 서유나 기자]\n김혜은이 김성오를 위해 김광규와 호텔을 찾았다. \n8월 ...
# 12  ■ 진행 : 송경철 앵커 \n■ 출연 : 배종호 세한대 교수, 조청래 전 통합당 여...
# 13  [OSEN=김보라 기자] 걸그룹 라붐 출신 율희가 3남매를 육아하는 일상을 공개했다...
# 14  [뉴스엔 한정원 기자]\n김빈우가 시어머니에게 서운함을 드러냈다.\n8월 1일 방송...
#
#                                          news_content
# 0   경기 파주시 이날 하루만 최대       폭우서울 도림천   대 남성 구조  이송 ...
# 1    월  일 방송된     토일드라마  트레인   회 극본 박가연 연출 류승진 이승훈...
# 2    하남시 미사 동행정복지센터는  월  일 미사 동 지역사회보장협의체와  하일위생환경...
# 3     온앤오프  소유가 뮤직비디오 촬영으로 인한 다이어트가 끝난 뒤 먹고 싶은 음식을...
# 4   빗썸 등 가상자산사업자도 금융당국에 자금세탁방지 업무 감독 받아야 \n       ...
# 5    일 방송된  최애 엔터테인먼트 에서는 계약서에 도장 찍자마자 연습실로 향하는 최애...
# 6   사법시험준비생모임 사준모 은 계약갱신청구권제를 도입한 개정 주택임대차보호법이 임차인...
# 7   일본에서 오늘  일   천   명의 코로나   확진자가 추가됐습니다 \n이로써   ...
# 8    한 번 다녀왔습니다 에서 기도훈이  살 연상 오윤아에 고백했다  \n 일 오후 방...
# 9   배우 유이가 자신의 매니저 영도씨가 잦은 장트러블로 휴게소를 찾자 결국 오열해 주변...
# 10   지창욱이 직영점 전환 제안을 받았다 \n 일 방송된     금토드라마  편의점 샛...
# 11   일 오후 방송된      전지적 참견 시점 에서는 유이와 매니저 영도씨의 일상이 ...
# 12  복팀의 코디로 출격한 배우 강기영은  홈즈 의 애청자로 밝히며  일요일은  신비한 ...
# 13  오바메양은     년  월 독일 도르트문트를 떠나 아스널 유니폼을 입었다  시즌 도...
# 14   월  일 방송된     토일드라마  사이코지만 괜찮아    회에서 고문영 서예지 ...
# 0                  다이노스가  월   일 두산과의 홈경기에 앞서 제  회 ...
# 1    한국 바둑의 미래를 이끌 루키들의 꿈의 무대      조아바이톤 루키바둑리그가  ...
# 2     우아한 친구들  유준상이 사강과 마주했다 \n 일 방송된 종합편성채널      ...
# 3   올해  번 째  공공구매력을 활용한 혁신제품의 공공조달시장 진입 지원 \n이번에 지...
# 4         제주삼다수 마스터스 루키시즌 대회  연패 눈앞이정은    언더파  위  ...
# 5   프로야구 키움 히어로즈가   안타를 터뜨리며 삼성 라이온즈를 대파하고  연승을 질주...
# 6   지하철  호선 강남역 부근이 침수돼 시민들이 불편을 겪었다  \n          ...
# 7    월  일 아이즈원    에는  여러부우운 저는 여러분 덕분에 너무너무 행복한   ...
# 8   연장   회말  사 만루에서 유격수 김재호의 호수비로 승리를 지킨 두산 선수들이 그...
# 9   배우 유이가  전지적 참견 시점 에 출연한 소감을 밝혔다  \n 일 오후 방송된  ...
# 10  오늘  일  저녁  시   분쯤 인천 만수동의 한 도로에서    가 경차와 가로수를...
# 11   월  일 방송된      금토드라마  우아한 친구들  연출 송현욱  박소연 극본 ...
# 12    출연   배종호 세한대 교수  조청래 전 통합당 여의도연구원 부원장 \n  아래...
# 13   걸그룹 라붐 출신 율희가  남매를 육아하는 일상을 공개했다 \n율희는  일 오후 ...
# 14   월  일 방송된      속풀이쇼 동치미 는  남편에게 반려견 보다 못한 아내 라...
#                                             news_name              pubdate  \
# 0           수도권 등 '물폭탄'에 사망 1명·곳곳 침수..내일도 최대 80mm(종합)  2020. 08. 01. 23:59
# 1             '트레인' 윤시윤, 평행세계 자신 전화에 패닉 "차엽은 공범" (종합)  2020. 08. 01. 23:55
# 2                              하남 미사2동 취약계층 선풍기 55대전달  2020. 08. 01. 23:55
# 3        '온앤오프' 소유 "다이어트 중, 달걀+치즈 라면+소맥 먹고 싶어" [TV캡처]  2020. 08. 01. 23:55
# 4                    더불어민주당 홍성국 의원, 가상화폐 돈세탁 감독법 대표발의  2020. 08. 01. 23:55
# 5   '최애 엔터테인먼트' 계약서 도장 찍자마자 연습! 미션곡 '주라주라', '로꾸거!!...  2020. 08. 01. 23:54
# 6                  '계약갱신청구권' 위헌 여부 가리나..헌재에 헌법소원심판 청구  2020. 08. 01. 23:54
# 7                일본 신규 확진 또 1천500명대..지자체, 일부 상점 휴업 요청  2020. 08. 01. 23:54
# 8                    '한다다' 기도훈, 연상 오윤아에게 "좋아해도 되냐" 고백  2020. 08. 01. 23:53
# 9                 '전참시' 유이, 매니저 영도씨의 잦은 장트러블에 결국 '오열'  2020. 08. 01. 23:51
# 10   [스브스夜] '편의점 샛별이' 한선화, 지창욱 되찾기 위한 중상모략.."김유정 쫓아내"  2020. 08. 01. 23:51
# 11                    '전참시' 전현무, 녹화 중 급 화장실行 "너무 급해서"  2020. 08. 01. 23:51
# 12            '구해줘 홈즈' 강기영,일산·김포·파주 일대 2억 원대 전세 매물 찾기  2020. 08. 01. 23:50
# 13           첼시, 지난 1월 오바메양 영입 기회 있었다..'높은 연봉에 관심 철회'  2020. 08. 01. 23:50
# 14                        '사이코지만 괜찮아' 수간호사, 서예지 母로 반전  2020. 08. 01. 23:50
# 0    NC, 김해고 황금사자기 우승 축하 행사.."풀뿌리 야구 발전 돕는다" [엠스플 이슈]  2020. 08. 01. 23:50
# 1                '바둑 꿈나무 향연장' 조아바이톤 루키바둑리그, 본격 레이스 돌입  2020. 08. 01. 23:48
# 2                 '우아한 친구들' 유준상, 사강 만났다..김원해 비밀에 한 발짝  2020. 08. 01. 23:47
# 3                                조달청 우수조달물품 47개 제품 지정  2020. 08. 01. 23:46
# 4                 오늘도 버디만 7개..19세 유해란, '와이어 투 와이어' 예약  2020. 08. 01. 23:45
# 5                           '23안타' 키움, 삼성 대파하고 5연승 질주  2020. 08. 01. 23:45
# 6                                 강한 비에 2호선 강남역 부근 침수  2020. 08. 01. 23:44
# 7            아이즈원 채원, 생일 기념 어린 시절 사진 공개..아기삵의 더 아기 시절  2020. 08. 01. 23:43
# 8                           두산, 연장접전 끝 NC 꺾고 전날 패배 설욕  2020. 08. 01. 23:42
# 9         '전참시' 유이 "매니저, 속마음 다 이야기 하는 친구, 소개하고 싶어 출연"  2020. 08. 01. 23:42
# 10                           SUV가 경차·가로수 들이받아..운전자 도주  2020. 08. 01. 23:42
# 11                  '우아한 친구들' 김혜은, 남편 김성오 위해 김광규와 호텔행  2020. 08. 01. 23:41
# 12                        與 '부동산 입법' 속도..野 반발 속 대응 고심  2020. 08. 01. 23:40
# 13       '최민환♥︎' 율희, 삼남매 엄마의 일상 "이제는 다투기도 한다"[★SHOT!]  2020. 08. 01. 23:40
# 14           김빈우 "시모, 반려견 걱정에 손주 보러 안 와 조금 서운"[결정적장면]  2020. 08. 01. 23:39
# 0           '온앤오프' 성시경, 신민아 상대역 과거 소환..엄정화 "입술 뭐야" 폭소  2020. 08. 01. 23:39
# 1         삼성 김진영 "기량과 팬 서비스 모두 '만점' 선수 꿈꾼다" [엠스플 KBL]  2020. 08. 01. 23:39
# 2                 '개훌륭' 강형욱 "맹견 통제 못하면 결국 도살장行" 충격 충고  2020. 08. 01. 23:38
# 3                    아베, 아베노마스크 벗었다..새로운 마스크는 "후쿠시마산"  2020. 08. 01. 23:38
# 4                        K리그 첫 유관중 경기, 장맛비에도 팬들에 큰 호응  2020. 08. 01. 23:37
# 5                     '온앤오프' 성시경, 배우로 활동할 당시 상대역은 신민아  2020. 08. 01. 23:37
# 6           '전참시' 김강훈, 양세형 팬심 고백 "너무 웃겨서 이 사람 뭐지 싶었다"  2020. 08. 01. 23:36
# 7                            의왕시 '랜선 트롯 청소년 가요제' 9월개최  2020. 08. 01. 23:36
# 8                 '전참시' 김강훈 "과거 전현무 예능에서 아빠, 짜증 많이 내"  2020. 08. 01. 23:35
# 9         '전참시' 유이, 매니저와 남매 케미 "왜 예쁘다는 말 안 해줘" [TV캡처]  2020. 08. 01. 23:35
# 10                                    LG하우시스의 리얼리티 벽지  2020. 08. 01. 23:34
# 11                        지역 최고의 효도상품, 대구한국일보 효콘서트 성료  2020. 08. 01. 23:34
# 12                            7월 승률 1위 kt..상승세는 계속된다!  2020. 08. 01. 23:34
# 13                   "소리 못 질러도 괜찮아"..'직관' 갈증 해소한 축구팬들  2020. 08. 01. 23:34
# 14                  '우아한 친구들' 송윤아, 父에 적개심 "다신 나타나지 마"  2020. 08. 01. 23:33
#
#                                        url  \
# 0   https://v.daum.net/v/20200801235926455
# 1   https://v.daum.net/v/20200801235556443
# 2   https://v.daum.net/v/20200801235522442
# 3   https://v.daum.net/v/20200801235511441
# 4   https://v.daum.net/v/20200801235505440
# 5   https://v.daum.net/v/20200801235428437
# 6   https://v.daum.net/v/20200801235408436
# 7   https://v.daum.net/v/20200801235401433
# 8   https://v.daum.net/v/20200801235311432
# 9   https://v.daum.net/v/20200801235102418
# 10  https://v.daum.net/v/20200801235101417
# 11  https://v.daum.net/v/20200801235100415
# 12  https://v.daum.net/v/20200801235022406
# 13  https://v.daum.net/v/20200801235005401
# 14  https://v.daum.net/v/20200801235003400
# 0   https://v.daum.net/v/20200801235003399
# 1   https://v.daum.net/v/20200801234804392
# 2   https://v.daum.net/v/20200801234739388
# 3   https://v.daum.net/v/20200801234632378
# 4   https://v.daum.net/v/20200801234510367
# 5   https://v.daum.net/v/20200801234500363
# 6   https://v.daum.net/v/20200801234402356
# 7   https://v.daum.net/v/20200801234324355
# 8   https://v.daum.net/v/20200801234212354
# 9   https://v.daum.net/v/20200801234200353
# 10  https://v.daum.net/v/20200801234200352
# 11  https://v.daum.net/v/20200801234123351
# 12  https://v.daum.net/v/20200801234021348
# 13  https://v.daum.net/v/20200801234016347
# 14  https://v.daum.net/v/20200801233956345
# 0   https://v.daum.net/v/20200801233947344
# 1   https://v.daum.net/v/20200801233912339
# 2   https://v.daum.net/v/20200801233829329
# 3   https://v.daum.net/v/20200801233814326
# 4   https://v.daum.net/v/20200801233751323
# 5   https://v.daum.net/v/20200801233733321
# 6   https://v.daum.net/v/20200801233648320
# 7   https://v.daum.net/v/20200801233631319
# 8   https://v.daum.net/v/20200801233529318
# 9   https://v.daum.net/v/20200801233503317
# 10  https://v.daum.net/v/20200801233447316
# 11  https://v.daum.net/v/20200801233423314
# 12  https://v.daum.net/v/20200801233412313
# 13  https://v.daum.net/v/20200801233410312
# 14  https://v.daum.net/v/20200801233333311
#
#                                               content  \
# 0   경기 파주시 이날 하루만 최대 124mm 폭우서울 도림천 80대 남성 구조..이송 ...
# 1   윤시윤이 평행세계 자신에게서 전화를 받았다. \n8월 1일 방송된 OCN 토일드라마...
# 2   하남 미사2동 취약계층 선풍기 55대 전달. 사진제공=하남시\n           ...
# 3   소유 / 사진=tvN 온앤오프\n           \n\n[스포츠투데이 김샛별 기...
# 4   빗썸 등 가상자산사업자도 금융당국에 자금세탁방지 업무 감독 받아야 \n\n\n\n ...
# 5   1일 방송된 '최애 엔터테인먼트'에서는 계약서에 도장 찍자마자 연습실로 향하는 최애...
# 6   사법시험준비생모임(사준모)은 계약갱신청구권제를 도입한 개정 주택임대차보호법이 임차인...
# 7   일본에서 오늘(1일) 1천536명의 코로나19 확진자가 추가됐습니다.\n이로써 NH...
# 8   한번 다녀왔습니다(사진=방송화면캡쳐)\n           \n\n\n'한 번 다녀...
# 9   [매일경제 스타투데이 손세현 객원기자]\n          \n배우 유이가 자신의 ...
# 10  [SBS funE | 김지수 에디터] 지창욱이 직영점 전환 제안을 받았다.\n1일 ...
# 11  MBC '전지적 참견 시점' 방송 화면 캡처 © 뉴스1\n           \n\...
# 12  '구해줘 홈즈' 강기영이 출연한다.MBC 제공\n           \n\n'구해줘...
# 13  [인터풋볼] 오종헌 기자= 첼시는 지난 1월 피에르 에메릭 오바메양(31, 아스널)...
# 14  사이코지만 괜찮아(사진=방송화면캡쳐)\n           \n\n\n수간호사 장영...
# 0   시구자로 나선 김해고 김준수 투수와 시포자 박무승 감독(사진=NC)\n       ...
# 1   사진=한국기원 제공\n           \n\n[스포츠투데이 김호진 기자] 한국 ...
# 2   [엑스포츠뉴스 나금주 기자] '우아한 친구들' 유준상이 사강과 마주했다.\n1일 방...
# 3   올해 3번 째, 공공구매력을 활용한 혁신제품의 공공조달시장 진입 지원 \n\n\n[...
# 4   KLPGA 제주삼다수 마스터스 루키시즌 대회 2연패 눈앞이정은6 14언더파 2위.....
# 5   프로야구 키움 히어로즈가 23안타를 터뜨리며 삼성 라이온즈를 대파하고 5연승을 질주...
# 6   [ 김경림 기자 ]\n          \n\n\n\n\n\n\n지하철 2호선 강남...
# 7   8월 1일 아이즈원 SNS에는 “여러부우운 저는 여러분 덕분에 너무너무 행복한 21...
# 8   연장 10회말 1사 만루에서 유격수 김재호의 호수비로 승리를 지킨 두산 선수들이 그...
# 9   매경닷컴 MK스포츠 손진아 기자\n배우 유이가 ‘전지적 참견 시점’에 출연한 소감을...
# 10  오늘(1일) 저녁 7시 40분쯤 인천 만수동의 한 도로에서 SUV가 경차와 가로수를...
# 11  [뉴스엔 서유나 기자]\n김혜은이 김성오를 위해 김광규와 호텔을 찾았다. \n8월 ...
# 12  ■ 진행 : 송경철 앵커 \n■ 출연 : 배종호 세한대 교수, 조청래 전 통합당 여...
# 13  [OSEN=김보라 기자] 걸그룹 라붐 출신 율희가 3남매를 육아하는 일상을 공개했다...
# 14  [뉴스엔 한정원 기자]\n김빈우가 시어머니에게 서운함을 드러냈다.\n8월 1일 방송...
# 0   [뉴스엔 이하나 기자]\n과거 드라마에 출연했던 성시경의 영상이 공개 됐다. \n8...
# 1   -김유택 아들 김진영, “농구 잘하고 팬 서비스도 완벽한 선수 꿈꾼다”\n\n\n-...
# 2   [스타뉴스 이시연 기자] \n          \n\n\n\n            ...
# 3   총리 주변 "후쿠시마 제조..부흥 의미" \n\n\n\n\n\n           ...
# 4   인천 가장 높은 좌석 점유율아숩게 경기는 광주에 패배 \n\n\n\n\n\n    ...
# 5   사진=tvN '온앤오프'\n           \n\n[아시아경제 김정호 기자] 가...
# 6   [마이데일리 = 양유진 기자] 아역배우 김강훈이 개그맨 양세형을 향한 팬심을 드러냈...
# 7   의왕시 진로 멘토링-‘청소년 랜선 트롯 가요제’ 포스터. 사진제공=의왕시\n    ...
# 8   전참시 김강훈 사진="전지적 참견 시점" 방송 캡처\n           \n\n ...
# 9   유이 매니저 / 사진=MBC 전지적 참견 시점\n           \n\n[스포츠...
# 10  LG하우시스가 고급스러운 패턴과 입체적인 질감을 갖춘 프리미엄 벽지 '디아망'을 2...
# 11  '현인의 환생' 조명섭, '장구의 신' 박서진이 꾸민 최고의 힐링 콘서트 \n\n\...
# 12  [앵커] \n7할 승률을 질주하며 화끈한 7월을 보낸 프로야구 kt가 홈런 선두 로...
# 13  [앵커] \n프로야구에 이어 프로축구도 코로나 19 사태 뒤 처음으로 관중 입장이 ...
# 14  [엑스포츠뉴스 나금주 기자] '우아한 친구들' 송윤아가 20년 전 아버지에게 어떤 ...
#
#                                          news_content
# 0   경기 파주시 이날 하루만 최대       폭우서울 도림천   대 남성 구조  이송 ...
# 1    월  일 방송된     토일드라마  트레인   회 극본 박가연 연출 류승진 이승훈...
# 2    하남시 미사 동행정복지센터는  월  일 미사 동 지역사회보장협의체와  하일위생환경...
# 3     온앤오프  소유가 뮤직비디오 촬영으로 인한 다이어트가 끝난 뒤 먹고 싶은 음식을...
# 4   빗썸 등 가상자산사업자도 금융당국에 자금세탁방지 업무 감독 받아야 \n       ...
# 5    일 방송된  최애 엔터테인먼트 에서는 계약서에 도장 찍자마자 연습실로 향하는 최애...
# 6   사법시험준비생모임 사준모 은 계약갱신청구권제를 도입한 개정 주택임대차보호법이 임차인...
# 7   일본에서 오늘  일   천   명의 코로나   확진자가 추가됐습니다 \n이로써   ...
# 8    한 번 다녀왔습니다 에서 기도훈이  살 연상 오윤아에 고백했다  \n 일 오후 방...
# 9   배우 유이가 자신의 매니저 영도씨가 잦은 장트러블로 휴게소를 찾자 결국 오열해 주변...
# 10   지창욱이 직영점 전환 제안을 받았다 \n 일 방송된     금토드라마  편의점 샛...
# 11   일 오후 방송된      전지적 참견 시점 에서는 유이와 매니저 영도씨의 일상이 ...
# 12  복팀의 코디로 출격한 배우 강기영은  홈즈 의 애청자로 밝히며  일요일은  신비한 ...
# 13  오바메양은     년  월 독일 도르트문트를 떠나 아스널 유니폼을 입었다  시즌 도...
# 14   월  일 방송된     토일드라마  사이코지만 괜찮아    회에서 고문영 서예지 ...
# 0                  다이노스가  월   일 두산과의 홈경기에 앞서 제  회 ...
# 1    한국 바둑의 미래를 이끌 루키들의 꿈의 무대      조아바이톤 루키바둑리그가  ...
# 2     우아한 친구들  유준상이 사강과 마주했다 \n 일 방송된 종합편성채널      ...
# 3   올해  번 째  공공구매력을 활용한 혁신제품의 공공조달시장 진입 지원 \n이번에 지...
# 4         제주삼다수 마스터스 루키시즌 대회  연패 눈앞이정은    언더파  위  ...
# 5   프로야구 키움 히어로즈가   안타를 터뜨리며 삼성 라이온즈를 대파하고  연승을 질주...
# 6   지하철  호선 강남역 부근이 침수돼 시민들이 불편을 겪었다  \n          ...
# 7    월  일 아이즈원    에는  여러부우운 저는 여러분 덕분에 너무너무 행복한   ...
# 8   연장   회말  사 만루에서 유격수 김재호의 호수비로 승리를 지킨 두산 선수들이 그...
# 9   배우 유이가  전지적 참견 시점 에 출연한 소감을 밝혔다  \n 일 오후 방송된  ...
# 10  오늘  일  저녁  시   분쯤 인천 만수동의 한 도로에서    가 경차와 가로수를...
# 11   월  일 방송된      금토드라마  우아한 친구들  연출 송현욱  박소연 극본 ...
# 12    출연   배종호 세한대 교수  조청래 전 통합당 여의도연구원 부원장 \n  아래...
# 13   걸그룹 라붐 출신 율희가  남매를 육아하는 일상을 공개했다 \n율희는  일 오후 ...
# 14   월  일 방송된      속풀이쇼 동치미 는  남편에게 반려견 보다 못한 아내 라...
# 0    월  일 방송된      온앤오프 에서 김동완의 집을 찾은 성시경은 연기에 대한 ...
# 1    김유택 아들 김진영   농구 잘하고 팬 서비스도 완벽한 선수 꿈꾼다 \n  지금보...
# 2    개는 훌륭하다 에서 강형욱이 맹견을 키우는 보호자에게 충고했다  \n 일 오후 방...
# 3               아베 총리가 전국민에게 배부했던 이른바  아베노마스크 아베의 ...
# 4               시즌 첫 유관중 경기가 열린 인천축구전용경기장  \n 시즌 첫...
# 5    가수 성시경과 김동완이 전원생활을 즐겼다 \n 일 오후 방송된      온앤오프 ...
# 6    아역배우 김강훈이 개그맨 양세형을 향한 팬심을 드러냈다  \n 일 밤 방송된   ...
# 7    의왕시가 코로나   사태 장기화로 진로체험 및 문화활동이 어려운 청소년을 위해 진...
# 8    일 오후 방송된      전지적 참견 시점 에 김강훈이 게스트로 출연했다 \n이날...
# 9     전참시  유이가 매니저와 찐 남매  케미 를 자랑했다  \n 일 방송된     ...
# 10    하우시스가 고급스러운 패턴과 입체적인 질감을 갖춘 프리미엄 벽지  디아망 을  ...
# 11   현인의 환생  조명섭   장구의 신  박서진이 꾸민 최고의 힐링 콘서트 \n 일 ...
# 12   할 승률을 질주하며 화끈한  월을 보낸 프로야구   가 홈런 선두 로하스 등을 앞...
# 13  프로야구에 이어 프로축구도 코로나    사태 뒤 처음으로 관중 입장이 허용됐습니다 ...
# 14    우아한 친구들  송윤아가   년 전 아버지에게 어떤 부탁을 했던 사실이 밝혀졌다...
#                                             news_name              pubdate  \
# 0           수도권 등 '물폭탄'에 사망 1명·곳곳 침수..내일도 최대 80mm(종합)  2020. 08. 01. 23:59
# 1             '트레인' 윤시윤, 평행세계 자신 전화에 패닉 "차엽은 공범" (종합)  2020. 08. 01. 23:55
# 2                              하남 미사2동 취약계층 선풍기 55대전달  2020. 08. 01. 23:55
# 3        '온앤오프' 소유 "다이어트 중, 달걀+치즈 라면+소맥 먹고 싶어" [TV캡처]  2020. 08. 01. 23:55
# 4                    더불어민주당 홍성국 의원, 가상화폐 돈세탁 감독법 대표발의  2020. 08. 01. 23:55
# 5   '최애 엔터테인먼트' 계약서 도장 찍자마자 연습! 미션곡 '주라주라', '로꾸거!!...  2020. 08. 01. 23:54
# 6                  '계약갱신청구권' 위헌 여부 가리나..헌재에 헌법소원심판 청구  2020. 08. 01. 23:54
# 7                일본 신규 확진 또 1천500명대..지자체, 일부 상점 휴업 요청  2020. 08. 01. 23:54
# 8                    '한다다' 기도훈, 연상 오윤아에게 "좋아해도 되냐" 고백  2020. 08. 01. 23:53
# 9                 '전참시' 유이, 매니저 영도씨의 잦은 장트러블에 결국 '오열'  2020. 08. 01. 23:51
# 10   [스브스夜] '편의점 샛별이' 한선화, 지창욱 되찾기 위한 중상모략.."김유정 쫓아내"  2020. 08. 01. 23:51
# 11                    '전참시' 전현무, 녹화 중 급 화장실行 "너무 급해서"  2020. 08. 01. 23:51
# 12            '구해줘 홈즈' 강기영,일산·김포·파주 일대 2억 원대 전세 매물 찾기  2020. 08. 01. 23:50
# 13           첼시, 지난 1월 오바메양 영입 기회 있었다..'높은 연봉에 관심 철회'  2020. 08. 01. 23:50
# 14                        '사이코지만 괜찮아' 수간호사, 서예지 母로 반전  2020. 08. 01. 23:50
# 0    NC, 김해고 황금사자기 우승 축하 행사.."풀뿌리 야구 발전 돕는다" [엠스플 이슈]  2020. 08. 01. 23:50
# 1                '바둑 꿈나무 향연장' 조아바이톤 루키바둑리그, 본격 레이스 돌입  2020. 08. 01. 23:48
# 2                 '우아한 친구들' 유준상, 사강 만났다..김원해 비밀에 한 발짝  2020. 08. 01. 23:47
# 3                                조달청 우수조달물품 47개 제품 지정  2020. 08. 01. 23:46
# 4                 오늘도 버디만 7개..19세 유해란, '와이어 투 와이어' 예약  2020. 08. 01. 23:45
# 5                           '23안타' 키움, 삼성 대파하고 5연승 질주  2020. 08. 01. 23:45
# 6                                 강한 비에 2호선 강남역 부근 침수  2020. 08. 01. 23:44
# 7            아이즈원 채원, 생일 기념 어린 시절 사진 공개..아기삵의 더 아기 시절  2020. 08. 01. 23:43
# 8                           두산, 연장접전 끝 NC 꺾고 전날 패배 설욕  2020. 08. 01. 23:42
# 9         '전참시' 유이 "매니저, 속마음 다 이야기 하는 친구, 소개하고 싶어 출연"  2020. 08. 01. 23:42
# 10                           SUV가 경차·가로수 들이받아..운전자 도주  2020. 08. 01. 23:42
# 11                  '우아한 친구들' 김혜은, 남편 김성오 위해 김광규와 호텔행  2020. 08. 01. 23:41
# 12                        與 '부동산 입법' 속도..野 반발 속 대응 고심  2020. 08. 01. 23:40
# 13       '최민환♥︎' 율희, 삼남매 엄마의 일상 "이제는 다투기도 한다"[★SHOT!]  2020. 08. 01. 23:40
# 14           김빈우 "시모, 반려견 걱정에 손주 보러 안 와 조금 서운"[결정적장면]  2020. 08. 01. 23:39
# 0           '온앤오프' 성시경, 신민아 상대역 과거 소환..엄정화 "입술 뭐야" 폭소  2020. 08. 01. 23:39
# 1         삼성 김진영 "기량과 팬 서비스 모두 '만점' 선수 꿈꾼다" [엠스플 KBL]  2020. 08. 01. 23:39
# 2                 '개훌륭' 강형욱 "맹견 통제 못하면 결국 도살장行" 충격 충고  2020. 08. 01. 23:38
# 3                    아베, 아베노마스크 벗었다..새로운 마스크는 "후쿠시마산"  2020. 08. 01. 23:38
# 4                        K리그 첫 유관중 경기, 장맛비에도 팬들에 큰 호응  2020. 08. 01. 23:37
# 5                     '온앤오프' 성시경, 배우로 활동할 당시 상대역은 신민아  2020. 08. 01. 23:37
# 6           '전참시' 김강훈, 양세형 팬심 고백 "너무 웃겨서 이 사람 뭐지 싶었다"  2020. 08. 01. 23:36
# 7                            의왕시 '랜선 트롯 청소년 가요제' 9월개최  2020. 08. 01. 23:36
# 8                 '전참시' 김강훈 "과거 전현무 예능에서 아빠, 짜증 많이 내"  2020. 08. 01. 23:35
# 9         '전참시' 유이, 매니저와 남매 케미 "왜 예쁘다는 말 안 해줘" [TV캡처]  2020. 08. 01. 23:35
# 10                                    LG하우시스의 리얼리티 벽지  2020. 08. 01. 23:34
# 11                        지역 최고의 효도상품, 대구한국일보 효콘서트 성료  2020. 08. 01. 23:34
# 12                            7월 승률 1위 kt..상승세는 계속된다!  2020. 08. 01. 23:34
# 13                   "소리 못 질러도 괜찮아"..'직관' 갈증 해소한 축구팬들  2020. 08. 01. 23:34
# 14                  '우아한 친구들' 송윤아, 父에 적개심 "다신 나타나지 마"  2020. 08. 01. 23:33
# 0           '온앤오프' 성시경X김동완, 결혼에 대한 속내 고백 "아직 철이 덜 든듯"  2020. 08. 01. 23:33
# 1                  '윤주태 멀티골' 서울, 성남 2-1 제압..광주, 인천 완파  2020. 08. 01. 23:33
# 2        '전참시' 김강훈 "5살 때 만난 전현무, 카메라 꺼지면 짜증 많이 냈다" 폭로  2020. 08. 01. 23:32
# 3                소프트뱅크 선수 코로나 확진 판정..NPB, 첫 공식전 취소 충격  2020. 08. 01. 23:31
# 4      '온앤오프' 성시경, '가평댁' 김동완家 방문→결혼관 고백 "막 살 에너지도 없다"  2020. 08. 01. 23:31
# 5                 '전참시' 유이 "91년생인 매니저, 이사님으로 오해받아" 폭소  2020. 08. 01. 23:30
# 6              가상화폐 비트코인 258,000원 상승한 13,674,000원에 거래  2020. 08. 01. 23:30
# 7                 '동치미' 전성애 "악역 전문 ♥장광, 평소엔 인자하고 따뜻해"  2020. 08. 01. 23:30
# 8                    '온앤오프' 성시경, 김동완 전원생활 극찬에 "꼬시지 마"  2020. 08. 01. 23:30
# 9                         '전참시' 유이, 털털한 형 같은 반전 매력 발산  2020. 08. 01. 23:30
# 10                             [08월 01일 22시] 1R 22시뉴스  2020. 08. 01. 23:30
# 11              '전참시' 유이, 나이 어린 노안 매니저 공개 "이사님이라고 오해"  2020. 08. 01. 23:29
# 12                '전참시' 김강훈 "예능으로 데뷔..전현무 당시 짜증 많이 내"  2020. 08. 01. 23:29
# 13              가수 한강, 도자기 감정에 가사 선물까지 받은 사연? '이상문TV'  2020. 08. 01. 23:27
# 14            '전참시' 전현무 "7년전 5살 김강훈, 라면 3봉지 끓여먹어 놀랐다"  2020. 08. 01. 23:26
#
#                                        url  \
# 0   https://v.daum.net/v/20200801235926455
# 1   https://v.daum.net/v/20200801235556443
# 2   https://v.daum.net/v/20200801235522442
# 3   https://v.daum.net/v/20200801235511441
# 4   https://v.daum.net/v/20200801235505440
# 5   https://v.daum.net/v/20200801235428437
# 6   https://v.daum.net/v/20200801235408436
# 7   https://v.daum.net/v/20200801235401433
# 8   https://v.daum.net/v/20200801235311432
# 9   https://v.daum.net/v/20200801235102418
# 10  https://v.daum.net/v/20200801235101417
# 11  https://v.daum.net/v/20200801235100415
# 12  https://v.daum.net/v/20200801235022406
# 13  https://v.daum.net/v/20200801235005401
# 14  https://v.daum.net/v/20200801235003400
# 0   https://v.daum.net/v/20200801235003399
# 1   https://v.daum.net/v/20200801234804392
# 2   https://v.daum.net/v/20200801234739388
# 3   https://v.daum.net/v/20200801234632378
# 4   https://v.daum.net/v/20200801234510367
# 5   https://v.daum.net/v/20200801234500363
# 6   https://v.daum.net/v/20200801234402356
# 7   https://v.daum.net/v/20200801234324355
# 8   https://v.daum.net/v/20200801234212354
# 9   https://v.daum.net/v/20200801234200353
# 10  https://v.daum.net/v/20200801234200352
# 11  https://v.daum.net/v/20200801234123351
# 12  https://v.daum.net/v/20200801234021348
# 13  https://v.daum.net/v/20200801234016347
# 14  https://v.daum.net/v/20200801233956345
# 0   https://v.daum.net/v/20200801233947344
# 1   https://v.daum.net/v/20200801233912339
# 2   https://v.daum.net/v/20200801233829329
# 3   https://v.daum.net/v/20200801233814326
# 4   https://v.daum.net/v/20200801233751323
# 5   https://v.daum.net/v/20200801233733321
# 6   https://v.daum.net/v/20200801233648320
# 7   https://v.daum.net/v/20200801233631319
# 8   https://v.daum.net/v/20200801233529318
# 9   https://v.daum.net/v/20200801233503317
# 10  https://v.daum.net/v/20200801233447316
# 11  https://v.daum.net/v/20200801233423314
# 12  https://v.daum.net/v/20200801233412313
# 13  https://v.daum.net/v/20200801233410312
# 14  https://v.daum.net/v/20200801233333311
# 0   https://v.daum.net/v/20200801233329310
# 1   https://v.daum.net/v/20200801233310305
# 2   https://v.daum.net/v/20200801233211290
# 3   https://v.daum.net/v/20200801233125282
# 4   https://v.daum.net/v/20200801233113280
# 5   https://v.daum.net/v/20200801233049275
# 6   https://v.daum.net/v/20200801233025272
# 7   https://v.daum.net/v/20200801233004269
# 8   https://v.daum.net/v/20200801233002268
# 9   https://v.daum.net/v/20200801233001266
# 10  https://v.daum.net/v/20200801233001265
# 11  https://v.daum.net/v/20200801232921260
# 12  https://v.daum.net/v/20200801232918258
# 13  https://v.daum.net/v/20200801232749247
# 14  https://v.daum.net/v/20200801232609243
#
#                                               content  \
# 0   경기 파주시 이날 하루만 최대 124mm 폭우서울 도림천 80대 남성 구조..이송 ...
# 1   윤시윤이 평행세계 자신에게서 전화를 받았다. \n8월 1일 방송된 OCN 토일드라마...
# 2   하남 미사2동 취약계층 선풍기 55대 전달. 사진제공=하남시\n           ...
# 3   소유 / 사진=tvN 온앤오프\n           \n\n[스포츠투데이 김샛별 기...
# 4   빗썸 등 가상자산사업자도 금융당국에 자금세탁방지 업무 감독 받아야 \n\n\n\n ...
# 5   1일 방송된 '최애 엔터테인먼트'에서는 계약서에 도장 찍자마자 연습실로 향하는 최애...
# 6   사법시험준비생모임(사준모)은 계약갱신청구권제를 도입한 개정 주택임대차보호법이 임차인...
# 7   일본에서 오늘(1일) 1천536명의 코로나19 확진자가 추가됐습니다.\n이로써 NH...
# 8   한번 다녀왔습니다(사진=방송화면캡쳐)\n           \n\n\n'한 번 다녀...
# 9   [매일경제 스타투데이 손세현 객원기자]\n          \n배우 유이가 자신의 ...
# 10  [SBS funE | 김지수 에디터] 지창욱이 직영점 전환 제안을 받았다.\n1일 ...
# 11  MBC '전지적 참견 시점' 방송 화면 캡처 © 뉴스1\n           \n\...
# 12  '구해줘 홈즈' 강기영이 출연한다.MBC 제공\n           \n\n'구해줘...
# 13  [인터풋볼] 오종헌 기자= 첼시는 지난 1월 피에르 에메릭 오바메양(31, 아스널)...
# 14  사이코지만 괜찮아(사진=방송화면캡쳐)\n           \n\n\n수간호사 장영...
# 0   시구자로 나선 김해고 김준수 투수와 시포자 박무승 감독(사진=NC)\n       ...
# 1   사진=한국기원 제공\n           \n\n[스포츠투데이 김호진 기자] 한국 ...
# 2   [엑스포츠뉴스 나금주 기자] '우아한 친구들' 유준상이 사강과 마주했다.\n1일 방...
# 3   올해 3번 째, 공공구매력을 활용한 혁신제품의 공공조달시장 진입 지원 \n\n\n[...
# 4   KLPGA 제주삼다수 마스터스 루키시즌 대회 2연패 눈앞이정은6 14언더파 2위.....
# 5   프로야구 키움 히어로즈가 23안타를 터뜨리며 삼성 라이온즈를 대파하고 5연승을 질주...
# 6   [ 김경림 기자 ]\n          \n\n\n\n\n\n\n지하철 2호선 강남...
# 7   8월 1일 아이즈원 SNS에는 “여러부우운 저는 여러분 덕분에 너무너무 행복한 21...
# 8   연장 10회말 1사 만루에서 유격수 김재호의 호수비로 승리를 지킨 두산 선수들이 그...
# 9   매경닷컴 MK스포츠 손진아 기자\n배우 유이가 ‘전지적 참견 시점’에 출연한 소감을...
# 10  오늘(1일) 저녁 7시 40분쯤 인천 만수동의 한 도로에서 SUV가 경차와 가로수를...
# 11  [뉴스엔 서유나 기자]\n김혜은이 김성오를 위해 김광규와 호텔을 찾았다. \n8월 ...
# 12  ■ 진행 : 송경철 앵커 \n■ 출연 : 배종호 세한대 교수, 조청래 전 통합당 여...
# 13  [OSEN=김보라 기자] 걸그룹 라붐 출신 율희가 3남매를 육아하는 일상을 공개했다...
# 14  [뉴스엔 한정원 기자]\n김빈우가 시어머니에게 서운함을 드러냈다.\n8월 1일 방송...
# 0   [뉴스엔 이하나 기자]\n과거 드라마에 출연했던 성시경의 영상이 공개 됐다. \n8...
# 1   -김유택 아들 김진영, “농구 잘하고 팬 서비스도 완벽한 선수 꿈꾼다”\n\n\n-...
# 2   [스타뉴스 이시연 기자] \n          \n\n\n\n            ...
# 3   총리 주변 "후쿠시마 제조..부흥 의미" \n\n\n\n\n\n           ...
# 4   인천 가장 높은 좌석 점유율아숩게 경기는 광주에 패배 \n\n\n\n\n\n    ...
# 5   사진=tvN '온앤오프'\n           \n\n[아시아경제 김정호 기자] 가...
# 6   [마이데일리 = 양유진 기자] 아역배우 김강훈이 개그맨 양세형을 향한 팬심을 드러냈...
# 7   의왕시 진로 멘토링-‘청소년 랜선 트롯 가요제’ 포스터. 사진제공=의왕시\n    ...
# 8   전참시 김강훈 사진="전지적 참견 시점" 방송 캡처\n           \n\n ...
# 9   유이 매니저 / 사진=MBC 전지적 참견 시점\n           \n\n[스포츠...
# 10  LG하우시스가 고급스러운 패턴과 입체적인 질감을 갖춘 프리미엄 벽지 '디아망'을 2...
# 11  '현인의 환생' 조명섭, '장구의 신' 박서진이 꾸민 최고의 힐링 콘서트 \n\n\...
# 12  [앵커] \n7할 승률을 질주하며 화끈한 7월을 보낸 프로야구 kt가 홈런 선두 로...
# 13  [앵커] \n프로야구에 이어 프로축구도 코로나 19 사태 뒤 처음으로 관중 입장이 ...
# 14  [엑스포츠뉴스 나금주 기자] '우아한 친구들' 송윤아가 20년 전 아버지에게 어떤 ...
# 0   [스포츠조선닷컴 정유나 기자] '온앤오프' 성시경과 김동완이 결혼에 대한 솔직한 생...
# 1   사진=한국프로축구연맹 제공\n           \n\n[스포츠투데이 김호진 기자]...
# 2   [TV리포트=김은정 기자] 김강훈이 전현무의 OFF모습을 폭로했다.\n1일 오후 방...
# 3   소프트뱅크의 홈구장 후쿠오카 페이페이돔./OSEN DB\n           \n\...
# 4   [OSEN=이승훈 기자] '온앤오프' 성시경과 김동완이 싹쓰리를 이을 새로운 레트로...
# 5   [마이데일리 = 양유진 기자] 배우 유이가 매니저에 얽힌 '웃픈' 사연을 공개했다....
# 6   [한국경제TV 라이온봇 기자]\n           \n\n\n\n\n\n[표]가상...
# 7   [뉴스엔 한정원 기자]\n전성애가 장광이 악한 사람이 아니라고 해명했다.\n8월 1...
# 8   매경닷컴 MK스포츠 손진아 기자\n가수 성시경이 전원 생활에 푹 빠졌다. \n1일 ...
# 9   [매일경제 스타투데이 손세현 객원기자]\n          \n배우 유이가 자신의 ...
# 10  1라디오 1R 22시뉴스 \n\n\n\n\n\n\n저작권자ⓒ KBS(news.kbs...
# 11  전지적 참견 시점 유이 김강훈\n           \n\n[티브이데일리 최하나 기...
# 12  MBC '전지적 참견 시점' 방송 화면 캡처 © 뉴스1\n           \n\...
# 13  [스포츠경향] \n\n\n\n            가수 한강이 아버지의 특별한 사연...
# 14  [뉴스엔 지연주 기자]\n방송인 전현무가 아역배우 김강훈의 먹성에 경악했다. \n8...
#
#                                          news_content
# 0   경기 파주시 이날 하루만 최대       폭우서울 도림천   대 남성 구조  이송 ...
# 1    월  일 방송된     토일드라마  트레인   회 극본 박가연 연출 류승진 이승훈...
# 2    하남시 미사 동행정복지센터는  월  일 미사 동 지역사회보장협의체와  하일위생환경...
# 3     온앤오프  소유가 뮤직비디오 촬영으로 인한 다이어트가 끝난 뒤 먹고 싶은 음식을...
# 4   빗썸 등 가상자산사업자도 금융당국에 자금세탁방지 업무 감독 받아야 \n       ...
# 5    일 방송된  최애 엔터테인먼트 에서는 계약서에 도장 찍자마자 연습실로 향하는 최애...
# 6   사법시험준비생모임 사준모 은 계약갱신청구권제를 도입한 개정 주택임대차보호법이 임차인...
# 7   일본에서 오늘  일   천   명의 코로나   확진자가 추가됐습니다 \n이로써   ...
# 8    한 번 다녀왔습니다 에서 기도훈이  살 연상 오윤아에 고백했다  \n 일 오후 방...
# 9   배우 유이가 자신의 매니저 영도씨가 잦은 장트러블로 휴게소를 찾자 결국 오열해 주변...
# 10   지창욱이 직영점 전환 제안을 받았다 \n 일 방송된     금토드라마  편의점 샛...
# 11   일 오후 방송된      전지적 참견 시점 에서는 유이와 매니저 영도씨의 일상이 ...
# 12  복팀의 코디로 출격한 배우 강기영은  홈즈 의 애청자로 밝히며  일요일은  신비한 ...
# 13  오바메양은     년  월 독일 도르트문트를 떠나 아스널 유니폼을 입었다  시즌 도...
# 14   월  일 방송된     토일드라마  사이코지만 괜찮아    회에서 고문영 서예지 ...
# 0                  다이노스가  월   일 두산과의 홈경기에 앞서 제  회 ...
# 1    한국 바둑의 미래를 이끌 루키들의 꿈의 무대      조아바이톤 루키바둑리그가  ...
# 2     우아한 친구들  유준상이 사강과 마주했다 \n 일 방송된 종합편성채널      ...
# 3   올해  번 째  공공구매력을 활용한 혁신제품의 공공조달시장 진입 지원 \n이번에 지...
# 4         제주삼다수 마스터스 루키시즌 대회  연패 눈앞이정은    언더파  위  ...
# 5   프로야구 키움 히어로즈가   안타를 터뜨리며 삼성 라이온즈를 대파하고  연승을 질주...
# 6   지하철  호선 강남역 부근이 침수돼 시민들이 불편을 겪었다  \n          ...
# 7    월  일 아이즈원    에는  여러부우운 저는 여러분 덕분에 너무너무 행복한   ...
# 8   연장   회말  사 만루에서 유격수 김재호의 호수비로 승리를 지킨 두산 선수들이 그...
# 9   배우 유이가  전지적 참견 시점 에 출연한 소감을 밝혔다  \n 일 오후 방송된  ...
# 10  오늘  일  저녁  시   분쯤 인천 만수동의 한 도로에서    가 경차와 가로수를...
# 11   월  일 방송된      금토드라마  우아한 친구들  연출 송현욱  박소연 극본 ...
# 12    출연   배종호 세한대 교수  조청래 전 통합당 여의도연구원 부원장 \n  아래...
# 13   걸그룹 라붐 출신 율희가  남매를 육아하는 일상을 공개했다 \n율희는  일 오후 ...
# 14   월  일 방송된      속풀이쇼 동치미 는  남편에게 반려견 보다 못한 아내 라...
# 0    월  일 방송된      온앤오프 에서 김동완의 집을 찾은 성시경은 연기에 대한 ...
# 1    김유택 아들 김진영   농구 잘하고 팬 서비스도 완벽한 선수 꿈꾼다 \n  지금보...
# 2    개는 훌륭하다 에서 강형욱이 맹견을 키우는 보호자에게 충고했다  \n 일 오후 방...
# 3               아베 총리가 전국민에게 배부했던 이른바  아베노마스크 아베의 ...
# 4               시즌 첫 유관중 경기가 열린 인천축구전용경기장  \n 시즌 첫...
# 5    가수 성시경과 김동완이 전원생활을 즐겼다 \n 일 오후 방송된      온앤오프 ...
# 6    아역배우 김강훈이 개그맨 양세형을 향한 팬심을 드러냈다  \n 일 밤 방송된   ...
# 7    의왕시가 코로나   사태 장기화로 진로체험 및 문화활동이 어려운 청소년을 위해 진...
# 8    일 오후 방송된      전지적 참견 시점 에 김강훈이 게스트로 출연했다 \n이날...
# 9     전참시  유이가 매니저와 찐 남매  케미 를 자랑했다  \n 일 방송된     ...
# 10    하우시스가 고급스러운 패턴과 입체적인 질감을 갖춘 프리미엄 벽지  디아망 을  ...
# 11   현인의 환생  조명섭   장구의 신  박서진이 꾸민 최고의 힐링 콘서트 \n 일 ...
# 12   할 승률을 질주하며 화끈한  월을 보낸 프로야구   가 홈런 선두 로하스 등을 앞...
# 13  프로야구에 이어 프로축구도 코로나    사태 뒤 처음으로 관중 입장이 허용됐습니다 ...
# 14    우아한 친구들  송윤아가   년 전 아버지에게 어떤 부탁을 했던 사실이 밝혀졌다...
# 0     온앤오프  성시경과 김동완이 결혼에 대한 솔직한 생각을 전했다 \n 일 방송된 ...
# 1      서울이 윤주태의 멀티골에 힘입어 성남  를 꺾고  연패를 탈출했다 \n서울은 ...
# 2    김강훈이 전현무의    모습을 폭로했다 \n 일 오후 방송된      전지적 참견...
# 3    일본프로야구 소프트뱅크 호크스 선수 가운데 코로나   확진자가 나왔다  \n소프트...
# 4     온앤오프  성시경과 김동완이 싹쓰리를 이을 새로운 레트로 케미 탄생을 예고했다 ...
# 5    배우 유이가 매니저에 얽힌  웃픈  사연을 공개했다  \n 일 밤 방송된     ...
# 6   현재 암호화폐 거래소  업비트 에 따르면 가상화폐 대장 격인 비트코인의 시세는 전일...
# 7    월  일 방송된      속풀이쇼 동치미 에는 전성애 장광 부부의 일상이 그려졌다...
# 8    일 오후 방송된      온앤오프 에서는 성시경이 김동완의 집을 방문하는 모습이 ...
# 9   배우 유이가 자신의 매니저 영도씨와 함께 출연해 털털한 매력을 발산했다 \n유이는 ...
# 10
# 11    전참시  유이가 나이 어린 매니저를 공개했다  \n이날 유이는 매니저에 대해  ...
# 12   일 오후 방송된      전지적 참견 시점 에서 김강훈은 드라마가 아닌 예능으로 ...
# 13              가수 한강이 아버지의 특별한 사연이 담긴 고미술품을 유튜브 채...
# 14   월  일 방송된      전지적 참견 시점 에서는 게스트로 출연한 유이와 김강훈의...
#                                        news_name              pubdate  \
# 0      수도권 등 '물폭탄'에 사망 1명·곳곳 침수..내일도 최대 80mm(종합)  2020. 08. 01. 23:59
# 1        '트레인' 윤시윤, 평행세계 자신 전화에 패닉 "차엽은 공범" (종합)  2020. 08. 01. 23:55
# 2                         하남 미사2동 취약계층 선풍기 55대전달  2020. 08. 01. 23:55
# 3   '온앤오프' 소유 "다이어트 중, 달걀+치즈 라면+소맥 먹고 싶어" [TV캡처]  2020. 08. 01. 23:55
# 4               더불어민주당 홍성국 의원, 가상화폐 돈세탁 감독법 대표발의  2020. 08. 01. 23:55
# ..                                           ...                  ...
# 10            '온앤오프' 성시경, 벌 앞에서 작아져..겁쟁이 버터왕자 등극  2020. 08. 01. 23:17
# 11                        김포시의회 공정무역 확산 토론회 5일개최  2020. 08. 01. 23:15
# 12         '온앤오프' 성시경 "김동완=기대고 싶은 친구, 선배 같고 멋있어"  2020. 08. 01. 23:15
# 13            '온앤오프' 성시경, 충격의 배우 활동 과거..상대역은 신민아  2020. 08. 01. 23:14
# 14       '동치미' 전성애, 반려견에 뽀뽀하는 장광에 "나랑 입 맞춘건 언젠지"  2020. 08. 01. 23:14
#
#                                        url  \
# 0   https://v.daum.net/v/20200801235926455
# 1   https://v.daum.net/v/20200801235556443
# 2   https://v.daum.net/v/20200801235522442
# 3   https://v.daum.net/v/20200801235511441
# 4   https://v.daum.net/v/20200801235505440
# ..                                     ...
# 10  https://v.daum.net/v/20200801231709213
# 11  https://v.daum.net/v/20200801231537206
# 12  https://v.daum.net/v/20200801231521204
# 13  https://v.daum.net/v/20200801231458203
# 14  https://v.daum.net/v/20200801231453202
#
#                                               content  \
# 0   경기 파주시 이날 하루만 최대 124mm 폭우서울 도림천 80대 남성 구조..이송 ...
# 1   윤시윤이 평행세계 자신에게서 전화를 받았다. \n8월 1일 방송된 OCN 토일드라마...
# 2   하남 미사2동 취약계층 선풍기 55대 전달. 사진제공=하남시\n           ...
# 3   소유 / 사진=tvN 온앤오프\n           \n\n[스포츠투데이 김샛별 기...
# 4   빗썸 등 가상자산사업자도 금융당국에 자금세탁방지 업무 감독 받아야 \n\n\n\n ...
# ..                                                ...
# 10  온앤오프 성시경 사진="온앤오프" 방송 캡처\n           \n\n 가수 성...
# 11  김포시의회 공정무역 정책토론회 포스터. 사진제공=김포시의회\n           \...
# 12  [뉴스엔 이하나 기자]\n성시경이 김동완을 향한 두터운 신뢰를 드러냈다. \n8월 ...
# 13  [엑스포츠뉴스 김예은 기자] 성시경의 배우 활동 과거가 공개됐다. \n1일 방송된 ...
# 14  [뉴스엔 한정원 기자]\n전성애가 남편 장광에게 서운함을 드러냈다.\n8월 1일 방...
#
#                                          news_content
# 0   경기 파주시 이날 하루만 최대       폭우서울 도림천   대 남성 구조  이송 ...
# 1    월  일 방송된     토일드라마  트레인   회 극본 박가연 연출 류승진 이승훈...
# 2    하남시 미사 동행정복지센터는  월  일 미사 동 지역사회보장협의체와  하일위생환경...
# 3     온앤오프  소유가 뮤직비디오 촬영으로 인한 다이어트가 끝난 뒤 먹고 싶은 음식을...
# 4   빗썸 등 가상자산사업자도 금융당국에 자금세탁방지 업무 감독 받아야 \n       ...
# ..                                                ...
# 10   일 오후 방송된      온앤오프 에서는 김동완과 성시경의 일상이 전파를 탔다 \...
# 11   김포시의회가 오는  일  공정무역 도시조성 추진 을 위한 정책토론회를 김포아트빌리...
# 12   월  일 방송된      온앤오프 에서 성시경은 김동완의 가평 집을 방문했다  \...
# 13   성시경의 배우 활동 과거가 공개됐다  \n 일 방송된      온앤오프 에서는 동...
# 14   월  일 방송된      속풀이쇼 동치미 에는 전성애 장광 부부의 일상이 그려졌다...
#
# [75 rows x 5 columns]
#                                        news_name              pubdate  \
# 0      수도권 등 '물폭탄'에 사망 1명·곳곳 침수..내일도 최대 80mm(종합)  2020. 08. 01. 23:59
# 1        '트레인' 윤시윤, 평행세계 자신 전화에 패닉 "차엽은 공범" (종합)  2020. 08. 01. 23:55
# 2                         하남 미사2동 취약계층 선풍기 55대전달  2020. 08. 01. 23:55
# 3   '온앤오프' 소유 "다이어트 중, 달걀+치즈 라면+소맥 먹고 싶어" [TV캡처]  2020. 08. 01. 23:55
# 4               더불어민주당 홍성국 의원, 가상화폐 돈세탁 감독법 대표발의  2020. 08. 01. 23:55
# ..                                           ...                  ...
# 10                           '집중호우'..위력과 안전 수칙은?  2020. 08. 01. 23:07
# 11      '편의점 샛별이' 지창욱 "소중한 사람 되어주고파" 김유정에 고백(종합)  2020. 08. 01. 23:07
# 12          [속보] 日 코로나 하루 확진 1536명..이틀 연속 1500명대  2020. 08. 01. 23:07
# 13                     '김보경 결승골' 전북, 포항에 2-1 역전승  2020. 08. 01. 23:07
# 14                 1일 추첨 로또 1등 6명에 34억원씩..지난주 3배  2020. 08. 01. 23:06
#
#                                        url  \
# 0   https://v.daum.net/v/20200801235926455
# 1   https://v.daum.net/v/20200801235556443
# 2   https://v.daum.net/v/20200801235522442
# 3   https://v.daum.net/v/20200801235511441
# 4   https://v.daum.net/v/20200801235505440
# ..                                     ...
# 10  https://v.daum.net/v/20200801230751166
# 11  https://v.daum.net/v/20200801230746164
# 12  https://v.daum.net/v/20200801230743162
# 13  https://v.daum.net/v/20200801230710159
# 14  https://v.daum.net/v/20200801230602155
#
#                                               content  \
# 0   경기 파주시 이날 하루만 최대 124mm 폭우서울 도림천 80대 남성 구조..이송 ...
# 1   윤시윤이 평행세계 자신에게서 전화를 받았다. \n8월 1일 방송된 OCN 토일드라마...
# 2   하남 미사2동 취약계층 선풍기 55대 전달. 사진제공=하남시\n           ...
# 3   소유 / 사진=tvN 온앤오프\n           \n\n[스포츠투데이 김샛별 기...
# 4   빗썸 등 가상자산사업자도 금융당국에 자금세탁방지 업무 감독 받아야 \n\n\n\n ...
# ..                                                ...
# 10  [앵커]\n일반적으로 1시간 강우량이 30mm를 넘으면 집중호우라고 정의합니다.\n...
# 11  [뉴스엔 서유나 기자]\n지창욱이 김유정에게 고백했다.\n8월 1일 방송된 SBS ...
# 12              [파이낸셜뉴스] \n\nⓒ 파이낸셜뉴스, 무단 전재 및 재배포 금지
# 13  김보경 / 사진=한국프로축구연맹 제공\n           \n\n[스포츠투데이 김...
# 14  제922회 로또6/45 1등 당첨번호는 '2·6·13·17·27·43' \n\n\n...
#
#                                          news_content
# 0   경기 파주시 이날 하루만 최대       폭우서울 도림천   대 남성 구조  이송 ...
# 1    월  일 방송된     토일드라마  트레인   회 극본 박가연 연출 류승진 이승훈...
# 2    하남시 미사 동행정복지센터는  월  일 미사 동 지역사회보장협의체와  하일위생환경...
# 3     온앤오프  소유가 뮤직비디오 촬영으로 인한 다이어트가 끝난 뒤 먹고 싶은 음식을...
# 4   빗썸 등 가상자산사업자도 금융당국에 자금세탁방지 업무 감독 받아야 \n       ...
# ..                                                ...
# 10  일반적으로  시간 강우량이     를 넘으면 집중호우라고 정의합니다 \n집중호우는 ...
# 11   월  일 방송된     금토드라마  편의점 샛별이  극본 손근주  연출 이명우  ...
# 12
# 13   전북 현대가 김보경의 결승골에 힘입어 포항 스틸러스를 제압했다 \n전북은  일 오...
# 14  제   회 로또      등 당첨번호는                   \n 일 추...
#
# [90 rows x 5 columns]
#                                        news_name              pubdate  \
# 0      수도권 등 '물폭탄'에 사망 1명·곳곳 침수..내일도 최대 80mm(종합)  2020. 08. 01. 23:59
# 1        '트레인' 윤시윤, 평행세계 자신 전화에 패닉 "차엽은 공범" (종합)  2020. 08. 01. 23:55
# 2                         하남 미사2동 취약계층 선풍기 55대전달  2020. 08. 01. 23:55
# 3   '온앤오프' 소유 "다이어트 중, 달걀+치즈 라면+소맥 먹고 싶어" [TV캡처]  2020. 08. 01. 23:55
# 4               더불어민주당 홍성국 의원, 가상화폐 돈세탁 감독법 대표발의  2020. 08. 01. 23:55
# ..                                           ...                  ...
# 10      '백종원♥' 소유진, 엄마아빠 반반 닮은 ♥둥이 셋째딸과 '행복한 순간'  2020. 08. 01. 22:59
# 11               '놀면 뭐하니' 비, 아내 김태희 광고 보고 법적 조치?  2020. 08. 01. 22:59
# 12        '살림남2' 박애리, 구한말 방불케 하는 옷장 공개 [★밤TView]  2020. 08. 01. 22:58
# 13                        부동산 규제 규탄하며 신발 던지는 시민들  2020. 08. 01. 22:57
# 14                           신발 던지는 부동산 규제 규탄 집회  2020. 08. 01. 22:57
#
#                                        url  \
# 0   https://v.daum.net/v/20200801235926455
# 1   https://v.daum.net/v/20200801235556443
# 2   https://v.daum.net/v/20200801235522442
# 3   https://v.daum.net/v/20200801235511441
# 4   https://v.daum.net/v/20200801235505440
# ..                                     ...
# 10  https://v.daum.net/v/20200801225931122
# 11  https://v.daum.net/v/20200801225902121
# 12  https://v.daum.net/v/20200801225811119
# 13  https://v.daum.net/v/20200801225751118
# 14  https://v.daum.net/v/20200801225740117
#
#                                               content  \
# 0   경기 파주시 이날 하루만 최대 124mm 폭우서울 도림천 80대 남성 구조..이송 ...
# 1   윤시윤이 평행세계 자신에게서 전화를 받았다. \n8월 1일 방송된 OCN 토일드라마...
# 2   하남 미사2동 취약계층 선풍기 55대 전달. 사진제공=하남시\n           ...
# 3   소유 / 사진=tvN 온앤오프\n           \n\n[스포츠투데이 김샛별 기...
# 4   빗썸 등 가상자산사업자도 금융당국에 자금세탁방지 업무 감독 받아야 \n\n\n\n ...
# ..                                                ...
# 10  [스포츠조선 이유나 기자] 배우 소유진이 눈에 넣어도 아프지 않을 셋째딸 세은 양과...
# 11  놀면 뭐하니(사진=방송화면캡쳐)\n           \n\n\n비가 아내 김태희의...
# 12  [스타뉴스 이시연 기자] \n          \n\n\n\n            ...
# 13  (서울=뉴스1) 박지혜 기자 = 6·17 규제 소급적용 피해자 구제를 위한 모임, ...
# 14  (서울=뉴스1) 박지혜 기자 = 6·17 규제 소급적용 피해자 구제를 위한 모임, ...
#
#                                          news_content
# 0   경기 파주시 이날 하루만 최대       폭우서울 도림천   대 남성 구조  이송 ...
# 1    월  일 방송된     토일드라마  트레인   회 극본 박가연 연출 류승진 이승훈...
# 2    하남시 미사 동행정복지센터는  월  일 미사 동 지역사회보장협의체와  하일위생환경...
# 3     온앤오프  소유가 뮤직비디오 촬영으로 인한 다이어트가 끝난 뒤 먹고 싶은 음식을...
# 4   빗썸 등 가상자산사업자도 금융당국에 자금세탁방지 업무 감독 받아야 \n       ...
# ..                                                ...
# 10   배우 소유진이 눈에 넣어도 아프지 않을 셋째딸 세은 양과 함께 찍은 행복이 넘치는...
# 11   일 오후 방송된      놀면 뭐하니  에서는 유두래곤 유재석   린다  이효리 ...
# 12   살림하는 남자들 시즌  에서 박애리가 구한말을 연상시키는 옷들을 공개했다 \n 일...
# 13
# 14
#
# [105 rows x 5 columns]
#                                        news_name              pubdate  \
# 0      수도권 등 '물폭탄'에 사망 1명·곳곳 침수..내일도 최대 80mm(종합)  2020. 08. 01. 23:59
# 1        '트레인' 윤시윤, 평행세계 자신 전화에 패닉 "차엽은 공범" (종합)  2020. 08. 01. 23:55
# 2                         하남 미사2동 취약계층 선풍기 55대전달  2020. 08. 01. 23:55
# 3   '온앤오프' 소유 "다이어트 중, 달걀+치즈 라면+소맥 먹고 싶어" [TV캡처]  2020. 08. 01. 23:55
# 4               더불어민주당 홍성국 의원, 가상화폐 돈세탁 감독법 대표발의  2020. 08. 01. 23:55
# ..                                           ...                  ...
# 10                     문지환,'마지막까지 최선을 다했지만' [사진]  2020. 08. 01. 22:52
# 11                       의정부시 바둑전용경기장 도시가치-경제활력↑  2020. 08. 01. 22:52
# 12                  대한의사협회 의대 증원 반대하며 14일 총파업 예고  2020. 08. 01. 22:51
# 13          부동산 정책 비판 집회 맞나.."'대깨문'들 애국시민에 사과하라"  2020. 08. 01. 22:51
# 14             '복면가왕' 코요태 신지와 특별한 인연 밝힌 복면가수 누구?  2020. 08. 01. 22:50
#
#                                        url  \
# 0   https://v.daum.net/v/20200801235926455
# 1   https://v.daum.net/v/20200801235556443
# 2   https://v.daum.net/v/20200801235522442
# 3   https://v.daum.net/v/20200801235511441
# 4   https://v.daum.net/v/20200801235505440
# ..                                     ...
# 10  https://v.daum.net/v/20200801225226077
# 11  https://v.daum.net/v/20200801225222075
# 12  https://v.daum.net/v/20200801225101073
# 13  https://v.daum.net/v/20200801225100072
# 14  https://v.daum.net/v/20200801225051071
#
#                                               content  \
# 0   경기 파주시 이날 하루만 최대 124mm 폭우서울 도림천 80대 남성 구조..이송 ...
# 1   윤시윤이 평행세계 자신에게서 전화를 받았다. \n8월 1일 방송된 OCN 토일드라마...
# 2   하남 미사2동 취약계층 선풍기 55대 전달. 사진제공=하남시\n           ...
# 3   소유 / 사진=tvN 온앤오프\n           \n\n[스포츠투데이 김샛별 기...
# 4   빗썸 등 가상자산사업자도 금융당국에 자금세탁방지 업무 감독 받아야 \n\n\n\n ...
# ..                                                ...
# 10  [OSEN=인천, 민경훈 기자] 1일 오후 인천 중구 인천축구전용경기장에서 '202...
# 11  안병용 의정부시장. 사진제공=의정부시\n           \n\n\n[의정부=파이...
# 12  12일까지 의대 정원 확대 등 철회하지 않으면 파업 \n\n\n[서울신문]\n\n\...
# 13  [현장] 여의도에서 2차 조세저항 집회.. "공산화·빨갱이·사회주의" 이념 발언 등...
# 14  '복면가왕' 코요태가 출연한다.MBC제공\n           \n\n복면가수가 코...
#
#                                          news_content
# 0   경기 파주시 이날 하루만 최대       폭우서울 도림천   대 남성 구조  이송 ...
# 1    월  일 방송된     토일드라마  트레인   회 극본 박가연 연출 류승진 이승훈...
# 2    하남시 미사 동행정복지센터는  월  일 미사 동 지역사회보장협의체와  하일위생환경...
# 3     온앤오프  소유가 뮤직비디오 촬영으로 인한 다이어트가 끝난 뒤 먹고 싶은 음식을...
# 4   빗썸 등 가상자산사업자도 금융당국에 자금세탁방지 업무 감독 받아야 \n       ...
# ..                                                ...
# 10    일 오후 인천 중구 인천축구전용경기장에서       하나원큐  리그   인천유나...
# 11   의정부시는 모든 시민이   분 거리 생활권 내에서 가깝고 저렴한 비용으로 즐길 수...
# 12              최대집 대한의사협회 회장이  일 오후 서울 용산구 대한의사협회...
# 13   여의도에서  차 조세저항 집회    공산화 빨갱이 사회주의  이념 발언 등 쏟아져...
# 14   일 오후 방송되는      복면가왕 에서는 여름특집을 맞이해 찾아온 오싹한 복면가...
#
# [120 rows x 5 columns]
#                                        news_name              pubdate  \
# 0      수도권 등 '물폭탄'에 사망 1명·곳곳 침수..내일도 최대 80mm(종합)  2020. 08. 01. 23:59
# 1        '트레인' 윤시윤, 평행세계 자신 전화에 패닉 "차엽은 공범" (종합)  2020. 08. 01. 23:55
# 2                         하남 미사2동 취약계층 선풍기 55대전달  2020. 08. 01. 23:55
# 3   '온앤오프' 소유 "다이어트 중, 달걀+치즈 라면+소맥 먹고 싶어" [TV캡처]  2020. 08. 01. 23:55
# 4               더불어민주당 홍성국 의원, 가상화폐 돈세탁 감독법 대표발의  2020. 08. 01. 23:55
# ..                                           ...                  ...
# 4                                      그린살피는 배선우  2020. 08. 01. 22:48
# 5                                      밝은표정의 김효주  2020. 08. 01. 22:48
# 6                                     벙커샷하는 신지원2  2020. 08. 01. 22:48
# 7                                     버디 성공한 김효주  2020. 08. 01. 22:48
# 8        '윤주태 멀티골' 서울, 성남 꺾고 3연패 탈출..전북, 포항에 역전승  2020. 08. 01. 22:48
#
#                                        url  \
# 0   https://v.daum.net/v/20200801235926455
# 1   https://v.daum.net/v/20200801235556443
# 2   https://v.daum.net/v/20200801235522442
# 3   https://v.daum.net/v/20200801235511441
# 4   https://v.daum.net/v/20200801235505440
# ..                                     ...
# 4   https://v.daum.net/v/20200801224842059
# 5   https://v.daum.net/v/20200801224839058
# 6   https://v.daum.net/v/20200801224836056
# 7   https://v.daum.net/v/20200801224834055
# 8   https://v.daum.net/v/20200801224831054
#
#                                               content  \
# 0   경기 파주시 이날 하루만 최대 124mm 폭우서울 도림천 80대 남성 구조..이송 ...
# 1   윤시윤이 평행세계 자신에게서 전화를 받았다. \n8월 1일 방송된 OCN 토일드라마...
# 2   하남 미사2동 취약계층 선풍기 55대 전달. 사진제공=하남시\n           ...
# 3   소유 / 사진=tvN 온앤오프\n           \n\n[스포츠투데이 김샛별 기...
# 4   빗썸 등 가상자산사업자도 금융당국에 자금세탁방지 업무 감독 받아야 \n\n\n\n ...
# ..                                                ...
# 4   [서울=뉴시스]김명원 기자 = 1일 제주시에 위치한 세인트포 골프&리조트에서 열린 ...
# 5   [서울=뉴시스]김명원 기자 = 1일 제주시에 위치한 세인트포 골프&리조트에서 열린 ...
# 6   [서울=뉴시스]김명원 기자 = 1일 제주시에 위치한 세인트포 골프&리조트에서 열린 ...
# 7   [서울=뉴시스]김명원 기자 = 1일 제주시에 위치한 세인트포 골프&리조트에서 열린 ...
# 8   프로축구 K리그1(1부) FC 서울이 최하위 팀 인천 유나이티드를 7연패로 몰아넣고...
#
#                                          news_content
# 0   경기 파주시 이날 하루만 최대       폭우서울 도림천   대 남성 구조  이송 ...
# 1    월  일 방송된     토일드라마  트레인   회 극본 박가연 연출 류승진 이승훈...
# 2    하남시 미사 동행정복지센터는  월  일 미사 동 지역사회보장협의체와  하일위생환경...
# 3     온앤오프  소유가 뮤직비디오 촬영으로 인한 다이어트가 끝난 뒤 먹고 싶은 음식을...
# 4   빗썸 등 가상자산사업자도 금융당국에 자금세탁방지 업무 감독 받아야 \n       ...
# ..                                                ...
# 4
# 5
# 6
# 7
# 8               최용수 감독이 물러난 뒤 김호영 감독대행 체제로 첫 경기를 치...
#
# [129 rows x 5 columns]

# %%
import pandas as pd
import re
import os
import sqlite3
import numpy as np

df = pd.read_csv('daum_news_test.csv', names=['order','news_name','pubdate','url', 'content'])   # 컬럼이름 지정
df.to_csv('daum_news_test_addCol.csv', encoding='utf-8-sig')

con = sqlite3.connect("news_test02.db")   # 데이터베이스 이름
c = con.cursor()

contents = []
contents_new = []

def preprocessing_articles(data):
    for content in data['content']:
        # print(content)
        
        # content = content.fillna("")
        content = str(content).split('\n')
        content = list(filter(lambda s: len(s) > 3, content))

        # 글 마지막에 항상 기자의 메일 주소가 추가되어 있다. 그 이후로 나오는 글은 불필요하므로 삭제함
        for i in range(1, len(content)):
            if '@' in content[-i]:
                break               
            if i == len(content)-1:
                i = 1
            content_prep = content[:-i]

        # 너무 짧거나, 광고, copyright, 사진설명, 메일 등 불필요한 단어가 포함되어 있을 경우 불필요한 문장으로 판단하고 삭제 처리
            content_prep = list(filter(lambda s: len(s) > 30 and \
                '▶' not in s and \
                    '©' not in s and \
                        '▲' not in s and \
                            '사진=' not in s and \
                                '사진제공=' not in s and \
                                    '@' not in s and \
                                        not re.findall("기자 *$", s) and \
                                            not re.findall("제공 *$", s) and \
                                                not re.findall("이하", s) and \
                                                    not re.findall("무단전재", s) and \
                                                        not re.findall("기자 *= *", s) , content_prep))

        # 언론사명이 들어간 prefix 삭제
        content_prep = list(map(lambda s: re.sub("\[.*\]", "", s), content_prep)) #[스포츠서울]
        content_prep = list(map(lambda s: re.sub("\(.*\=.*\)", "", s), content_prep)) #(서울=뉴시스)
        content_prep = list(map(lambda s: re.sub("\【.*\=.*\】", "", s), content_prep)) #【파이낸셜뉴스 포천=강근주 기자】
        content_prep = list(map(lambda s: re.sub('[^가-힣]',' ', s), content_prep)) # 한글 제외 영문, 한자, 숫자, 특수문자 모두 제거 

        contents.append('\n'.join(content))
        contents_new.append('\n'.join(content_prep))

    data['news_content'] = contents_new

    return data


if __name__ == "__main__":
        
    file = 'daum_news_test_addCol.csv'
    data = pd.read_csv(file)

    base_name, ext = os.path.splitext(os.path.basename(file))
    output_file = "{}_{}{}".format(base_name, "prep", ext)   # 파일이름을 위에서 저장한 파일이름에 prep을 붙여 생성

    data_prep = preprocessing_articles(data)
    data_prep['news_content'].replace('', np.nan, inplace=True)    # 빈셀이 있는 행을 삭제하기 위해 NaN으로 변경
    data_prep_drop = data_prep.dropna(axis=0)
    data_prep_drop_dup = data_prep_drop.drop_duplicates(['news_content'], keep='first', inplace=False, ignore_index=True)   # 중복값 제거
    result = data_prep_drop_dup[['news_name', 'pubdate', 'url', 'content', 'news_content']]  # 비교를 위해 content(원본데이터) 추가, news_content가 전처리된 데이터
    result.to_sql('news_dummy', con, if_exists='append')         # DB에 news_dummy 라는 테이블 이름으로 저장
    con.commit()
    con.close()
    result.to_csv(output_file, index=None, encoding='utf-8-sig')   # 테이터 확인을 위해 csv파일로 저장

# %%
import glob
import pandas as pd
import re
import os
import sqlite3
import numpy as np


daumNews_dir = glob.glob('./glob_test/*.csv')


contents_new = []
cnt = 0
def preprocessing_articles(data):
    for content in data['content']:
        # print(content)

        # content = content.fillna("")
        content = str(content).split('\n')
        content = list(filter(lambda s: len(s) > 3, content))

        # 글 마지막에 항상 기자의 메일 주소가 추가되어 있다. 그 이후로 나오는 글은 불필요하므로 삭제함
        for i in range(1, len(content)):
            if '@' in content[-i]:
                break               
            if i == len(content)-1:
                i = 1
            content_prep = content[:-i]

        # 너무 짧거나, 광고, copyright, 사진설명, 메일 등 불필요한 단어가 포함되어 있을 경우 불필요한 문장으로 판단하고 삭제 처리
            content_prep = list(filter(lambda s: len(s) > 30 and \
                '▶' not in s and \
                    '©' not in s and \
                        '▲' not in s and \
                            '사진=' not in s and \
                                '사진제공=' not in s and \
                                    '@' not in s and \
                                        not re.findall("기자 *$", s) and \
                                            not re.findall("제공 *$", s) and \
                                                not re.findall("이하", s) and \
                                                    not re.findall("무단전재", s) and \
                                                        not re.findall("기자 *= *", s) , content_prep))

        # 언론사명이 들어간 prefix 삭제
        content_prep = list(map(lambda s: re.sub("\[.*\]", "", s), content_prep)) #[스포츠서울]
        content_prep = list(map(lambda s: re.sub("\(.*\=.*\)", "", s), content_prep)) #(서울=뉴시스)
        content_prep = list(map(lambda s: re.sub("\【.*\=.*\】", "", s), content_prep)) #【파이낸셜뉴스 포천=강근주 기자】
        # content_prep = list(map(lambda s: re.sub('[^A-Za-z가-힣]',' ', s), content_prep)) # 한글 제외 영문, 한자, 숫자, 특수문자 모두 제거 
        content_prep = list(map(lambda s: re.sub('[^가-힣]',' ', s), content_prep)) # 한글 제외 영문, 한자, 숫자, 특수문자 모두 제거 


        contents_new.append('\n'.join(content_prep))
        # print('for 안',len(contents_new))
    # cnt =+ 1
    # print(cnt, contents_new)
    # print('for 밖',len(contents_new))
    data['news_content'] = contents_new
    return data


if __name__ == "__main__":
    # con = sqlite3.connect("glob_test.db")   # 데이터베이스 이름
    # # c = con.cursor()
    # c = con.cursor()
    # c.execute('DROP TABLE IF EXISTS `news_dummy`;')
    # c.execute('''           
    #         CREATE TABLE `news_dummy` (
    #             `news_id` INTEGER NOT NULL PRIMARY KEY AUTOINCREMENT,
    #             `news_name` TEXT NOT NULL,
    #             `pubdate` TEXT NOT NULL,
    #             `url` TEXT NOT NULL,
    #             `news_content` TEXT NOT NULL
    #         );

    # ''')

    for daumNews in daumNews_dir:
        df = pd.read_csv(daumNews, names=['order','news_name','pubdate','url', 'content'])   # 컬럼이름 지정
        df = df.drop(['order'], axis=1)
        # print(df)
        data_prep = preprocessing_articles(df)
        # print(data_prep)
        # data_prep['news_content'] = data_prep['news_content'].str.replace(' ', '')
        # data_prep['news_content'] = data_prep['news_content'].str.replace('\n',' ')
        # data_prep['news_content'] = data_prep['news_content'].str.strip()
        # data_prep['news_content'] = data_prep['news_content'].replace('', np.nan)    # 빈셀이 있는 행을 삭제하기 위해 NaN으로 변경
        # data_prep_drop = data_prep.dropna(axis=0)
        # data_prep_drop_dup = data_prep_drop.drop_duplicates(['news_content'], keep='first', inplace=False, ignore_index=True)   # 중복값 제거
        # result = data_prep_drop_dup[['news_name', 'pubdate', 'url', 'news_content']]  # 비교를 위해 content(원본데이터) 추가, news_content가 전처리된 데이터
        # print(result)
        # c = con.cursor()
        # result.to_sql('news_dummy', con, if_exists='append', index=False)         # DB에 news_dummy 라는 테이블 이름으로 저장
    
    # con.commit()
    # con.close()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-49-2ed5f5ec24df> in <module>
#      79         df = df.drop(['order'], axis=1)
#      80         # print(df)
# ---> 81         data_prep = preprocessing_articles(df)
#      82         # print(data_prep)
#      83         # data_prep['news_content'] = data_prep['news_content'].str.replace(' ', '')
#
# <ipython-input-49-2ed5f5ec24df> in preprocessing_articles(data)
#      55     # print(cnt, contents_new)
#      56     # print('for 밖',len(contents_new))
# ---> 57     data['news_content'] = contents_new
#      58     return data
#      59
#
# C:\Python\Python36\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3042         else:
#    3043             # set column
# -> 3044             self._set_item(key, value)
#    3045
#    3046     def _setitem_slice(self, key: slice, value):
#
# C:\Python\Python36\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3118         """
#    3119         self._ensure_valid_index(value)
# -> 3120         value = self._sanitize_column(key, value)
#    3121         NDFrame._set_item(self, key, value)
#    3122
#
# C:\Python\Python36\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3766
#    3767             # turn me into an ndarray
# -> 3768             value = sanitize_index(value, self.index)
#    3769             if not isinstance(value, (np.ndarray, Index)):
#    3770                 if isinstance(value, list) and len(value) > 0:
#
# C:\Python\Python36\lib\site-packages\pandas\core\internals\construction.py in sanitize_index(data, index)
#     746     if len(data) != len(index):
#     747         raise ValueError(
# --> 748             "Length of values "
#     749             f"({len(data)}) "
#     750             "does not match length of index "
#
# ValueError: Length of values (30) does not match length of index (15)

# %%
data_prep
# Out:
#                                           news_name              pubdate  \
# 0                    BRITAIN FORMULA ONE GRAND PRIX  2020. 08. 01. 23:59
# 1       GERMANY TRAVEL PANDEMIC CORONAVIRUS COVID19  2020. 08. 01. 23:59
# 2                    BRITAIN FORMULA ONE GRAND PRIX  2020. 08. 01. 23:59
# 3         수도권 등 '물폭탄'에 사망 1명·곳곳 침수..내일도 최대 80mm(종합)  2020. 08. 01. 23:59
# 4       GERMANY TRAVEL PANDEMIC CORONAVIRUS COVID19  2020. 08. 01. 23:59
# ...                                             ...                  ...
# 705211     거리두기 2.5단계 속 정기국회 개막준비..공공의대·공수처·4차추경 쟁점  2020. 08. 31. 00:00
# 705212            "아 옛날이여" 해태제과, 고향만두·허니버터칩 영광 되찾을까  2020. 08. 31. 00:00
# 705213             김도훈의 놀라움과 감동 "그래서 이청용, 이청용 하나봐요"  2020. 08. 31. 00:00
# 705214                                     [인사] 병무청  2020. 08. 31. 00:00
# 705215                  톤은 같게, 소재는 다르게 세련된 톤온톤 스타일링  2020. 08. 31. 00:00
#
#                                            url  \
# 0       https://v.daum.net/v/20200801235958458
# 1       https://v.daum.net/v/20200801235935457
# 2       https://v.daum.net/v/20200801235932456
# 3       https://v.daum.net/v/20200801235926455
# 4       https://v.daum.net/v/20200801235925454
# ...                                        ...
# 705211  https://v.daum.net/v/20200831000003423
# 705212  https://v.daum.net/v/20200831000003422
# 705213  https://v.daum.net/v/20200831000003421
# 705214  https://v.daum.net/v/20200831000003420
# 705215  https://v.daum.net/v/20200831000002419
#
#                                                   content  \
# 0       British Formula One Grand Prix \n\n\nepa085790...
# 1       German Federal Foreign Office issues travel wa...
# 2       British Formula One Grand Prix \n\n\nepa085790...
# 3       경기 파주시 이날 하루만 최대 124mm 폭우서울 도림천 80대 남성 구조..이송 ...
# 4       German Federal Foreign Office issues travel wa...
# ...                                                   ...
# 705211  9월 1일 정기국회 개막, 100일 대장정 돌입4차 추경안과 2차 재난지원금 첫 쟁...
# 705212  '고향만두' 출시 이후 지난 2012년까지 줄곧 국내 냉동 만두시장 점유율 1위를 ...
# 705213  ▲ 즐거운 울산 현대 김도훈 감독 ⓒ한국프로축구연맹\n           \n\n[...
# 705214  (서울=뉴스1) = ◆병무청 <승진>▷서기관 Δ병역자원국 황주하 Δ사회복무국 김형숙...
# 705215  베이지 컬러만큼 톤온톤 스타일링을 하기 좋은 컬러가 있 \n\n\n\n\n\n\n\...
#
#                                              news_content
# 0                                                     NaN
# 1                                                     NaN
# 2                                                     NaN
# 3       경기 파주시 이날 하루만 최대       폭우서울 도림천   대 남성 구조  이송 ...
# 4                                                     NaN
# ...                                                   ...
# 705211  월  일 정기국회 개막     일 대장정 돌입 차 추경안과  차 재난지원금 첫 쟁정...
# 705212  지난     년까지 무려   여 년간 냉동 만두시장  위를 지키던 해태제과가 올해 ...
# 705213  그래서 이청용  이청용 하는 것 같아요    김도훈 울산 현대 감독도  쌍용  이청...
# 705214      병무청  승진  서기관  병역자원국 황주하  사회복무국 김형숙  사회복무국 송민선
# 705215  베이지 컬러만큼 톤온톤 스타일링을 하기 좋은 컬러가 있  베이지 컬러만큼 톤온톤 스...
#
# [705216 rows x 5 columns]

# %%
result
# Out:
#                                            news_name              pubdate  \
# 0          수도권 등 '물폭탄'에 사망 1명·곳곳 침수..내일도 최대 80mm(종합)  2020. 08. 01. 23:59
# 1            '트레인' 윤시윤, 평행세계 자신 전화에 패닉 "차엽은 공범" (종합)  2020. 08. 01. 23:55
# 2                             하남 미사2동 취약계층 선풍기 55대전달  2020. 08. 01. 23:55
# 3       '온앤오프' 소유 "다이어트 중, 달걀+치즈 라면+소맥 먹고 싶어" [TV캡처]  2020. 08. 01. 23:55
# 4                   더불어민주당 홍성국 의원, 가상화폐 돈세탁 감독법 대표발의  2020. 08. 01. 23:55
# ...                                              ...                  ...
# 530762      거리두기 2.5단계 속 정기국회 개막준비..공공의대·공수처·4차추경 쟁점  2020. 08. 31. 00:00
# 530763             "아 옛날이여" 해태제과, 고향만두·허니버터칩 영광 되찾을까  2020. 08. 31. 00:00
# 530764              김도훈의 놀라움과 감동 "그래서 이청용, 이청용 하나봐요"  2020. 08. 31. 00:00
# 530765                                      [인사] 병무청  2020. 08. 31. 00:00
# 530766                   톤은 같게, 소재는 다르게 세련된 톤온톤 스타일링  2020. 08. 31. 00:00
#
#                                            url  \
# 0       https://v.daum.net/v/20200801235926455
# 1       https://v.daum.net/v/20200801235556443
# 2       https://v.daum.net/v/20200801235522442
# 3       https://v.daum.net/v/20200801235511441
# 4       https://v.daum.net/v/20200801235505440
# ...                                        ...
# 530762  https://v.daum.net/v/20200831000003423
# 530763  https://v.daum.net/v/20200831000003422
# 530764  https://v.daum.net/v/20200831000003421
# 530765  https://v.daum.net/v/20200831000003420
# 530766  https://v.daum.net/v/20200831000002419
#
#                                              news_content
# 0       경기 파주시 이날 하루만 최대       폭우서울 도림천   대 남성 구조  이송 ...
# 1       월  일 방송된     토일드라마  트레인   회 극본 박가연 연출 류승진 이승훈 ...
# 2       하남시 미사 동행정복지센터는  월  일 미사 동 지역사회보장협의체와  하일위생환경이...
# 3       온앤오프  소유가 뮤직비디오 촬영으로 인한 다이어트가 끝난 뒤 먹고 싶은 음식을 밝...
# 4       빗썸 등 가상자산사업자도 금융당국에 자금세탁방지 업무 감독 받아야          ...
# ...                                                   ...
# 530762  월  일 정기국회 개막     일 대장정 돌입 차 추경안과  차 재난지원금 첫 쟁정...
# 530763  지난     년까지 무려   여 년간 냉동 만두시장  위를 지키던 해태제과가 올해 ...
# 530764  그래서 이청용  이청용 하는 것 같아요    김도훈 울산 현대 감독도  쌍용  이청...
# 530765      병무청  승진  서기관  병역자원국 황주하  사회복무국 김형숙  사회복무국 송민선
# 530766  베이지 컬러만큼 톤온톤 스타일링을 하기 좋은 컬러가 있  베이지 컬러만큼 톤온톤 스...
#
# [530767 rows x 4 columns]

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 530767 entries, 0 to 530766
# Data columns (total 4 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   news_name     530767 non-null  object
#  1   pubdate       530767 non-null  object
#  2   url           530767 non-null  object
#  3   news_content  530767 non-null  object
# dtypes: object(4)
# memory usage: 16.2+ MB

# %%
result['news_content']
# Out:
# 0         경기 파주시 이날 하루만 최대       폭우서울 도림천   대 남성 구조  이송 ...
# 1         월  일 방송된     토일드라마  트레인   회 극본 박가연 연출 류승진 이승훈 ...
# 2         하남시 미사 동행정복지센터는  월  일 미사 동 지역사회보장협의체와  하일위생환경이...
# 3         온앤오프  소유가 뮤직비디오 촬영으로 인한 다이어트가 끝난 뒤 먹고 싶은 음식을 밝...
# 4         빗썸 등 가상자산사업자도 금융당국에 자금세탁방지 업무 감독 받아야          ...
#                                 ...
# 530762    월  일 정기국회 개막     일 대장정 돌입 차 추경안과  차 재난지원금 첫 쟁정...
# 530763    지난     년까지 무려   여 년간 냉동 만두시장  위를 지키던 해태제과가 올해 ...
# 530764    그래서 이청용  이청용 하는 것 같아요    김도훈 울산 현대 감독도  쌍용  이청...
# 530765        병무청  승진  서기관  병역자원국 황주하  사회복무국 김형숙  사회복무국 송민선
# 530766    베이지 컬러만큼 톤온톤 스타일링을 하기 좋은 컬러가 있  베이지 컬러만큼 톤온톤 스...
# Name: news_content, Length: 530767, dtype: object

# %%
result
# Out:
#                                           news_name              pubdate  \
# 0                    BRITAIN FORMULA ONE GRAND PRIX  2020. 08. 01. 23:59
# 1       GERMANY TRAVEL PANDEMIC CORONAVIRUS COVID19  2020. 08. 01. 23:59
# 2         수도권 등 '물폭탄'에 사망 1명·곳곳 침수..내일도 최대 80mm(종합)  2020. 08. 01. 23:59
# 3       GERMANY TRAVEL PANDEMIC CORONAVIRUS COVID19  2020. 08. 01. 23:59
# 4                              California Wildfires  2020. 08. 01. 23:57
# ...                                             ...                  ...
# 567592     거리두기 2.5단계 속 정기국회 개막준비..공공의대·공수처·4차추경 쟁점  2020. 08. 31. 00:00
# 567593            "아 옛날이여" 해태제과, 고향만두·허니버터칩 영광 되찾을까  2020. 08. 31. 00:00
# 567594             김도훈의 놀라움과 감동 "그래서 이청용, 이청용 하나봐요"  2020. 08. 31. 00:00
# 567595                                     [인사] 병무청  2020. 08. 31. 00:00
# 567596                  톤은 같게, 소재는 다르게 세련된 톤온톤 스타일링  2020. 08. 31. 00:00
#
#                                            url  \
# 0       https://v.daum.net/v/20200801235958458
# 1       https://v.daum.net/v/20200801235935457
# 2       https://v.daum.net/v/20200801235926455
# 3       https://v.daum.net/v/20200801235925454
# 4       https://v.daum.net/v/20200801235718444
# ...                                        ...
# 567592  https://v.daum.net/v/20200831000003423
# 567593  https://v.daum.net/v/20200831000003422
# 567594  https://v.daum.net/v/20200831000003421
# 567595  https://v.daum.net/v/20200831000003420
# 567596  https://v.daum.net/v/20200831000002419
#
#                                              news_content  \
# 0       British Formula One Grand Prix \nepa         B...
# 1       German Federal Foreign Office issues travel wa...
# 2       경기 파주시 이날 하루만 최대    mm 폭우서울 도림천   대 남성 구조  이송 ...
# 3       German Federal Foreign Office issues travel wa...
# 4       A firefighter battles a brush fire at the Appl...
# ...                                                   ...
# 567592   월  일 정기국회 개막     일 대장정 돌입 차 추경안과  차 재난지원금 첫 쟁...
# 567593   지난     년까지 무려   여 년간 냉동 만두시장  위를 지키던 해태제과가 올해...
# 567594    그래서 이청용  이청용 하는 것 같아요   \n김도훈 울산 현대 감독도  쌍용 ...
# 567595      병무청  승진  서기관  병역자원국 황주하  사회복무국 김형숙  사회복무국 송민선
# 567596  베이지 컬러만큼 톤온톤 스타일링을 하기 좋은 컬러가 있 \n베이지 컬러만큼 톤온톤 ...
#
#                                                  remove_n
# 0       British Formula One Grand Prix epa         Bri...
# 1       German Federal Foreign Office issues travel wa...
# 2       경기 파주시 이날 하루만 최대    mm 폭우서울 도림천   대 남성 구조  이송 ...
# 3       German Federal Foreign Office issues travel wa...
# 4       A firefighter battles a brush fire at the Appl...
# ...                                                   ...
# 567592   월  일 정기국회 개막     일 대장정 돌입 차 추경안과  차 재난지원금 첫 쟁...
# 567593   지난     년까지 무려   여 년간 냉동 만두시장  위를 지키던 해태제과가 올해...
# 567594    그래서 이청용  이청용 하는 것 같아요   김도훈 울산 현대 감독도  쌍용  이...
# 567595      병무청  승진  서기관  병역자원국 황주하  사회복무국 김형숙  사회복무국 송민선
# 567596  베이지 컬러만큼 톤온톤 스타일링을 하기 좋은 컬러가 있 베이지 컬러만큼 톤온톤 스타...
#
# [567597 rows x 5 columns]
